# %%
import json
import pandas as pd
import numpy as np
import re
from collections import Counter
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
# 📌 3. JSON 데이터 로드
file_path = "../data/tokenized_data_제거3-1.json"
with open(file_path, "r", encoding="utf-8") as f:
    data = json.load(f)

# 📌 4. 데이터프레임 변환
df = pd.DataFrame(data)

# %%
df
# Out:
#                                 title  \
# 0                        朝鲜试射导弹亚太骤起波澜
# 1                            美朝关系开始解冻
# 2          美日韩间谍云集朝鲜周边空中侦察地面窃听 - 国际经济
# 3                美日韩紧盯朝鲜射导弹(图) - 国际经济
# 4                     美国朝鲜问题特使称美愿与朝对话
# ...                               ...
# 1017            詹德斌：韩国政局变动，美国要做的不应是施压
# 1018               朝鲜谴责美韩军事挑衅导致地区局势恶化
# 1019    朝鲜外务省：美韩军事挑衅行为导致地区局势恶化 - 国际频道
# 1020  石破茂与特朗普会面，美日“小集团”谋划“大算盘” | 国际识局
# 1021             外交部批驳美日韩涉台、涉南海问题消极表态
#
#                                                    link                 date  \
# 0     https://www.gmw.cn/01gmrb/2006-07/12/content_4...  2006-07-12T00:00:00
# 1     https://www.gmw.cn/01gmrb/2007-03/08/content_5...  2007-03-08T00:00:00
# 2     http://intl.ce.cn/zj/200809/19/t20080919_16855...  2008-09-19T00:00:00
# 3     http://intl.ce.cn/zj/200902/11/t20090211_18171...  2009-02-11T00:00:00
# 4         https://world.huanqiu.com/article/9CaKrnJlEWs  2009-03-07T00:00:00
# ...                                                 ...                  ...
# 1017  https://hqtime.huanqiu.com/share/article/4Ky1A...  2025-01-07T00:00:00
# 1018  http://www.xinhuanet.com/20250126/55a39b230ccf...  2025-01-26T00:00:00
# 1019  https://world.gmw.cn/2025-01/26/content_378203...  2025-01-26T00:00:00
# 1020  http://intl.ce.cn/qqss/202502/09/t20250209_392...  2025-02-09T00:00:00
# 1021  https://www.xinhuanet.com/world/20250217/8c936...  2025-02-17T00:00:00
#
#                                                 content source quarter  \
# 0     7月5日，朝鲜连续发射7枚导弹，引起国际社会震惊。近日，美日在安理会积极推动制裁朝鲜的议案，...    光明网  2006Q3
# 1     被外界视为“破冰之旅”的朝鲜副外相金桂冠3月5至6日在纽约与美国助理国务卿希尔就两国关系正常...    光明网  2007Q1
# 2     神秘，这是朝鲜留给外界的印象。 正因为神秘，一些国家的情报机构费尽心机，通过投放卫星、派遣侦...  中国经济网  2008Q3
# 3     改进型“大浦洞2号”据说可攻击美本土，甚至可能具有搭载核弹头技术 朝鲜政府最近频繁发出朝韩关...  中国经济网  2009Q1
# 4     新华网首尔3月7日电 (记者李拯宇 干玉兰) 美国朝鲜问题特使斯蒂芬·博斯沃思7日在韩国说，...    环球网  2009Q1
# ...                                                 ...    ...     ...
# 1017  美国国务卿布林肯1月5日抵达韩国。这看上去似乎是一次礼仪性道别之旅，但防止韩国“后弹劾政局”...    环球网  2025Q1
# 1018  新华社首尔1月26日电 据朝中社26日报道，朝鲜外务省对外政策室长当天发表谈话，谴责美韩近期...    新华网  2025Q1
# 1019  中新网1月26日电据朝中社报道，当地时间1月26日，朝鲜外务省对外政策室长发表谈话，谴责美韩...    光明网  2025Q1
# 0     朝鲜 连续 发射 7 枚 导弹 引起 国际 社会 震惊 。 美 日 安理会 推动 制裁 朝鲜...  2006-2009H
# 1     外界 视为 破冰 之 旅 朝鲜 副外相 金桂冠 5 纽约 美国 助理 国务卿 希尔 国 关系...  2006-2009H
# 2     神秘 朝鲜 留给 外界 印象 。 正 神秘 国家 情报 机构 费尽心机 投放 卫星 派遣 侦...  2006-2009H
# 3     改进型 大浦洞 2 据说 攻击 美 本土 具有 搭载 核 弹头 技术 朝鲜 政府 最近 频繁...  2006-2009H
# 4     新华网 首尔 电 李拯宇 干玉兰 美国 朝鲜 问题 特使 斯蒂芬博斯沃思 韩国 美国 朝鲜 ...  2006-2009H
# ...                                                 ...         ...
# 1017  美国 国务卿 布林肯 抵达 韩国 。 看上去 似乎 礼仪性 道别 之 旅 防止 韩国 后 弹...      2025H1
# 1018  首尔 电 朝中社 朝鲜 外务省 对外 政策 室长 谈话 谴责 美 韩 朝 军事 挑衅 行为 ...      2025H1
# 1019  中新网 电 朝中社 朝鲜 外务省 对外 政策 室长 谈话 谴责 美 韩 朝 军事 挑衅 行为...      2025H1
# 1020  中新网 电 孟湘君 特朗普 当选 新 任 美国 总统 后 意大利 以色列 等 国 领导人 先...      2025H1
# 1021  北京 电 马卓言 孙素颖 针对 美 日 韩 外长 德国 慕尼黑 举行 会晤 三 国 联合 声...      2025H1
#
# [1022 rows x 13 columns]

# %%
 # 불용어 리스트 정의
chinese_stopwords =  set([
    "的", "了", "在", "是", "和", "与", "也", "有", "对", "就", "以", "将", "要",
    "但", "其", "而", "此", "我们", "他们", "你们", "可以", "但是", "这样", "这个",
    "其中", "其中之一", "包括", "根据", "由于", "通过", "此外", "同时",
    "记者", "新闻", "媒体", "采访", "发表", "宣布", "透露", "介绍", "报道称",
    "指出", "强调", "证实", "承认", "评价", "评论", "提到", "解释", "分析",
    "总结", "预测", "预计", "关注", "反映", "说明", "进一步",
    "今天", "昨天", "明天", "日前", "近日", "本周", "上周", "下周", "目前",
    "现在", "过去", "未来", "今年", "去年", "明年", "此前", "随后", "当地",
    "相关", "部门", "官员", "发言人", "部长", "事务",
    "一", "二", "这", "不", "可能", "都", "才", "可", "一直", "到", "如果", "带来",
    "十分", "称", "个", "次", "因", "因此", "最", "即", "当天", "因为", "曾",
    "号", "第", "相当", "两", "很", "所以", "各种", "从而", "仍", "为了", "以及",
    "据", "并", "过", "几", "立即", "着", "于", "为", "说", "却", "使", "还",
    "来说", "至", "会", "除了", "被", "外", "若", "更", "已经", "已", "大大", "不仅",
    "能够", "再", "一些", "明确", "作为", "向",  "是否", "积极", "讨论",
    "越来越", "甚至", "出于", "以来", "重启", "近期", "依然", "影响", "之间", "重点",
    "方面", "力度", "报道", "如何", "周年", "文章", "前往", "通讯社", "事情",
    "社论", "非常", "上午", "时间", "它们", "应该", "不断", "结束", "愿意",
    "最后", "开始", "缺乏", "自己", "调查", "今后", "乃至", "特别", "深化",
    "即将", "类似", "什么", "没有", "方向", "更为", "需要", "做出",
    "公司", "平台", "环球", "时报", "人民", "日报", "新华社", "看起来",
    "凡是", "将", "丨"
])
# "月", "日", "年"

# %%
def remove_english_stopwords_dates(text, chinese_stopwords):
    # 1️⃣ 숫자만 있는 단어 삭제 (예: "2023", "123")
    text = re.sub(r'\b\d+\b', '', text)

    # 2️⃣ 날짜 패턴 제거 (예: "5日", "7月")
    text = re.sub(r'\d+[日月年]', '', text)

    # 3️⃣ 문자열을 공백 기준으로 분할
    token_list = text.split()

    # 4️⃣ 불용어 제거
    filtered_list = [word for word in token_list if word not in chinese_stopwords]

    return " ".join(filtered_list)

# DataFrame 적용
df["filtered_content"] = df["filtered_content"].apply(lambda x: remove_english_stopwords_dates(x, chinese_stopwords))

# %%
# 2️⃣ 전체 분기 기준 IDF 계산

# 전체 분기 리스트 및 개수
quarters = df["input_half"].unique()
Q = len(quarters)  # 전체 분기 수

# 단어별 등장 분기 수 계산
term_quarter_count = {}

for input_quarter in quarters:
    # 해당 분기의 모든 문서에서 등장한 단어 목록 추출
    quarter_texts = df[df["input_half"] == input_quarter]["filtered_content"].tolist()
    unique_words = set(" ".join(quarter_texts).split())  # 토큰을 한 단어로 인식
    for word in unique_words:
        term_quarter_count[word] = term_quarter_count.get(word, 0) + 1

# 전체 분기 기준 IDF 계산
idf_scores = {word: np.log(Q / df_t) for word, df_t in term_quarter_count.items()}

# %%
# 3️⃣ 분기별 TF 계산 (각 분기를 하나의 문서로 취급)

# 분기별 텍스트 결합 (분기 단위로 하나의 문서로 취급)
quarter_texts = df.groupby("input_half")["filtered_content"].apply(lambda x: " ".join(x)).reset_index()

# TF 벡터라이저 적용
vectorizer = TfidfVectorizer(use_idf=False, token_pattern=r'[^ ]+')  # 공백을 기준으로 토큰을 단일 단어로 인식
tf_matrix = vectorizer.fit_transform(quarter_texts["filtered_content"])
tf_df = pd.DataFrame(tf_matrix.toarray(), columns=vectorizer.get_feature_names_out())

# IDF 적용하여 최종 TF-IDF 계산
for word in tf_df.columns:
    if word in idf_scores:
        tf_df[word] *= idf_scores[word]

# 분기 정보 추가
tf_df = pd.concat([tf_df, quarter_texts[['input_half']].reset_index(drop=True)], axis=1)

# %%
# 🔹 분기별 TF-IDF 점수가 높은 상위 10개 단어 출력 (세부 점수 포함)
result_text = ""
for quarter in tf_df['input_half'].unique():
    quarter_data = tf_df[tf_df['input_half'] == quarter].drop(columns=['input_half'])
    num_documents = df[df['input_half'] == quarter].shape[0]
    top_words = quarter_data.T.sum(axis=1).sort_values(ascending=False).head(20)
    top_keywords = [(kw, round(top_words[kw], 4)) for kw in top_words.index]

    result_text += f"{quarter}반기 중요 키워드 (문서 수: {num_documents}개):\n"
    result_text += ", ".join([f"{kw}({avg_score}점)" for kw, avg_score in top_keywords]) + "\n\n"

print(result_text)
# Out:
# 2006-2009H반기 중요 키워드 (문서 수: 14개):
# 葛瑞格森(0.0449점), 间谍(0.0433점), 澳门(0.0431점), 侦察机(0.0391점), 金正日(0.0361점), 金正男(0.0359점), 纽金特(0.0359점), 汇业(0.0359점), 金桂冠(0.0359점), 发射(0.0335점), 希尔(0.0306점), 大浦洞(0.0303점), 总参谋部(0.0288점), 第１７１８(0.0269점), 自救(0.0269점), 谍报(0.0269점), 导弹(0.0263점), 卫星(0.0223점), 产量(0.0215점), 煤矿(0.0215점)
# 2019H1반기 중요 키워드 (문서 수: 15개):
# 沙纳汉(0.1068점), 照射(0.0688점), 文喜相(0.0626점), 特金(0.0498점), 岩屋毅(0.0456점), 印太(0.0444점), 特朗普(0.0416점), 雷达(0.0402점), 报告(0.0376점), 河井克行(0.0356점), 特金会(0.0356점), 飞行物(0.0344점), 河内(0.0299점), 巡逻机(0.0296점), 斯蒂芬比根(0.0285점), 蓬佩奥(0.0275점), 火控(0.0262점), 天皇(0.0256점), 制导(0.0241점), 道歉(0.0234점)
#
# 2019H2반기 중요 키워드 (문서 수: 53개):
# 博尔顿(0.0648점), 续签(0.0587점), 埃斯珀(0.0453점), 清单(0.0353점), 出口(0.0352점), 调停(0.0304점), 白色(0.029점), 终止(0.0277점), 半导体(0.0251점), 蓬佩奥(0.024점), 北极(0.0229점), 管制(0.0227점), 曼谷(0.0227점), 史迪威(0.0226점), 康京和(0.0226점), 失效(0.0196점), 镇海(0.0193점), 军情(0.0185점), 移出(0.0181점), 原材料(0.0163점)
#
# 2020H1반기 중요 키워드 (문서 수: 6개):
# 哈里斯(0.1214점), 分担额(0.085점), 海湾(0.0774점), 康京和(0.0684점), 防卫费(0.0666점), 护航(0.0666점), 中东(0.0589점), 霍尔木兹(0.0581점), 阿曼湾(0.0567점), 茂木敏充(0.0484점), 胡子(0.0453점), 李家成(0.0435점), 蓄须(0.0425점), 茂木(0.0425점), 在先(0.0387점), 赔偿案(0.0387점), 埃斯珀(0.0387점), 蓬佩奥(0.0342점), 到期(0.034점), 火箭炮(0.0333점)
#
# 2020H2반기 중요 키워드 (문서 수: 5개):
# 印太(0.1114점), 网络化(0.0946점), 战机(0.0892점), f35(0.0873점), 组装(0.0609점), 续签(0.0603점), 拜登(0.0555점), 赫尔维(0.0504점), 尹卓(0.0487점), f35b(0.0473점), 出云级(0.0378점), 名古屋(0.0378점), 概念(0.0378점), 起降(0.0365점), 航母(0.0359점), 百余(0.0345점), 尖阁(0.0345점), 埃斯珀(0.0345점), 增购(0.0345점), 肺炎(0.0303점)
#
# 2021H1반기 중요 키워드 (문서 수: 21개):
# 半导体(0.1188점), 拜登(0.071점), 白皮书(0.0441점), 供应链(0.0421점), 芯片(0.0403점), 海恩斯(0.0394점), 伊丽莎白(0.0351점), 红旗(0.0329점), 奥斯汀(0.0318점), 印太(0.0296점), 疫苗(0.0281점), 曹卫东(0.0281점), 女王号(0.0245점), 徐薰(0.0219점), 韩朝(0.0219점), 产业(0.0216점), 金圣(0.021점), 改装(0.018점), 航母化(0.0175점), 审定(0.0175점)
#
# 2021H2반기 중요 키워드 (문서 수: 11개):
# 舍曼(0.1059점), 副外长(0.092점), 厅长(0.073점), 巡航(0.0576점), 奥运会(0.044점), 崔钟建(0.0365점), 排海(0.0312점), 李相烈(0.0292점), 更变(0.0274점), 崔钟健(0.0274점), 远程(0.0272점), 导弹(0.0264점), 奥运(0.0249점), 独岛(0.0242점), 试射(0.0222점), 福岛(0.022점), 文在寅(0.0219점), 精确(0.0219점), 旭日旗(0.0219점), 警察(0.02점)
#
# 2022H1반기 중요 키워드 (문서 수: 13개):
# 尹锡悦(0.2612점), 逮捕令(0.1881점), 石破茂(0.163점), 戒严(0.1003점), 公调处(0.094점), 陈洋(0.094점), 特朗普(0.0858점), 布林肯(0.0579점), 郭嘉昆(0.047점), 弹劾(0.0378점), 职权(0.0378점), 赵兑烈(0.0376점), 警方(0.0376점), 逮捕(0.0336점), 有效期(0.0321점), 韩德洙(0.0321점), 火力战(0.0313점), 互吹(0.0313점), 反射性(0.0313점), 拜登(0.0313점)

# %%
print(quarters, Q)
# Out:
# ['2006-2009Q' '2010Q1' '2010Q3' '2010Q4' '2011Q1' '2011Q3' '2011Q4'
#  '2012Q1' '2012Q2' '2012Q3' '2012Q4' '2013Q1' '2013Q2' '2013Q3' '2013Q4'
#  '2014Q1' '2014Q2' '2014Q3' '2014Q4' '2015Q1' '2015Q2' '2015Q3' '2015Q4'
#  '2016Q1' '2016Q2' '2016Q3' '2016Q4' '2017Q1' '2017Q2' '2017Q3' '2017Q4'
#  '2018Q1' '2018Q2' '2018Q3' '2018Q4' '2019Q1' '2019Q2' '2019Q3' '2019Q4'
#  '2020Q1' '2020Q3' '2020Q4' '2021Q1' '2021Q2' '2021Q3' '2021Q4' '2022Q1'
#  '2022Q2' '2022Q3' '2022Q4' '2023Q1' '2023Q2' '2023Q3' '2023Q4' '2024Q1'
#  '2024Q2' '2024Q3' '2024Q4' '2025Q1'] 59

# %%
import pandas as pd

# 저장할 데이터 리스트 생성
data = []
for quarter in tf_df['input_quarter'].unique():
    num_documents = df[df['input_quarter'] == quarter].shape[0]
    data.append([quarter, num_documents])

# DataFrame 생성
count_df = pd.DataFrame(data, columns=['분기', '문서 수'])

# CSV 파일로 저장
# count_df.to_csv('quarterly_document_counts.csv', index=False, encoding='utf-8-sig')

# %%
count_df
# Out:
#             분기  문서 수
# 0   2006-2009Q    14
# 1       2010Q1     1
# 2       2010Q3     2
# 3       2010Q4     8
# 4       2011Q1     6
# 5       2011Q3     1
# 6       2011Q4     2
# 7       2012Q1     6
# 8       2012Q2    17
# 9       2012Q3    10
# 10      2012Q4    15
# 11      2013Q1    18
# 12      2013Q2    36
# 13      2013Q3     4
# 14      2013Q4    14
# 15      2014Q1    28
# 16      2014Q2    15
# 17      2014Q3    11
# 18      2014Q4    18
# 19      2015Q1    12
# 20      2015Q2    26
# 21      2015Q3     9
# 22      2015Q4    21
# 23      2016Q1    44
# 24      2016Q2    18
# 25      2016Q3    54
# 26      2016Q4    24
# 27      2017Q1    36
# 28      2017Q2    20
# 29      2017Q3    13
# 30      2017Q4    10
# 31      2018Q1     9
# 32      2018Q2     3
# 33      2018Q3     3
# 34      2018Q4     1
# 35      2019Q1    10
# 36      2019Q2     5
# 37      2019Q3    39
# 38      2019Q4    14
# 39      2020Q1     6
# 40      2020Q3     4
# 41      2020Q4     1
# 42      2021Q1     8
# 43      2021Q2    13
# 44      2021Q3     5
# 45      2021Q4     6
# 46      2022Q1     5
# 47      2022Q2     8
# 48      2022Q3    15
# 49      2022Q4    12
# 50      2023Q1    27
# 51      2023Q2    45
# 52      2023Q3   116
# 53      2023Q4    40
# 54      2024Q1    20
# 55      2024Q2    45
# 56      2024Q3    21
# 57      2024Q4    22
# 58      2025Q1     6
