# %%
import json
import pandas as pd
import re
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
# 📌 3. JSON 데이터 로드
file_path = "../data/news.json"
with open(file_path, "r", encoding="utf-8") as f:
    data = json.load(f)

# 📌 4. 데이터프레임 변환
df = pd.DataFrame(data)

# %%
df["year"] = df["quarter"].str[:4].astype(int)  # "2006Q3" → 2006

# 📌 2006~2009년 데이터를 "2006-2009Q"로 그룹화, 나머지는 기존 분기(YYYYQ#) 유지
df["input_quarter"] = df["quarter"].apply(lambda x: "2006-2009Q" if int(x[:4]) in range(2006, 2010) else x)
df["input_year"] = df["year"].apply(lambda x: "2006-2009" if 2006 <= x <= 2009 else str(x))

# %%
import re

def remove_english_stopwords_dates(text):
    # 영어 단어 제거 (단어뿐만 아니라 단독 알파벳도 포함)
    text = re.sub(r'[a-zA-Z]+', '', text)

    # 날짜 패턴 제거 (예: "5日", "7月")
    text = re.sub(r'\d+[日月]', '', text)

    # 공백 제거 (텍스트가 비어있지 않게)
    text = text.strip()

    return text

# DataFrame 적용
df["tokenized_content"] = df["tokenized_content"].apply(remove_english_stopwords_dates)

# %%
df
# Out:
#                                 title  \
# 0                        朝鲜试射导弹亚太骤起波澜
# 1                            美朝关系开始解冻
# 2          美日韩间谍云集朝鲜周边空中侦察地面窃听 - 国际经济
# 3                美日韩紧盯朝鲜射导弹(图) - 国际经济
# 4                     美国朝鲜问题特使称美愿与朝对话
# ...                               ...
# 1034            詹德斌：韩国政局变动，美国要做的不应是施压
# 1035               朝鲜谴责美韩军事挑衅导致地区局势恶化
# 1036    朝鲜外务省：美韩军事挑衅行为导致地区局势恶化 - 国际频道
# 1037  石破茂与特朗普会面，美日“小集团”谋划“大算盘” | 国际识局
# 1038             外交部批驳美日韩涉台、涉南海问题消极表态
#
#                                                    link        date  \
# 0     https://www.gmw.cn/01gmrb/2006-07/12/content_4...  2006-07-12
# 1     https://www.gmw.cn/01gmrb/2007-03/08/content_5...  2007-03-08
# 2     http://intl.ce.cn/zj/200809/19/t20080919_16855...  2008-09-19
# 3     http://intl.ce.cn/zj/200902/11/t20090211_18171...  2009-02-11
# 4         https://world.huanqiu.com/article/9CaKrnJlEWs  2009-03-07
# ...                                                 ...         ...
# 1034  https://hqtime.huanqiu.com/share/article/4Ky1A...  2025-01-07
# 1035  http://www.xinhuanet.com/20250126/55a39b230ccf...  2025-01-26
# 1036  https://world.gmw.cn/2025-01/26/content_378203...  2025-01-26
# 1037  http://intl.ce.cn/qqss/202502/09/t20250209_392...  2025-02-09
# 1038  https://www.xinhuanet.com/world/20250217/8c936...  2025-02-17
#
#                                                 content source quarter  \
# 0     7月5日，朝鲜连续发射7枚导弹，引起国际社会震惊。近日，美日在安理会积极推动制裁朝鲜的议案，...    光明网  2006Q3
# 1     被外界视为“破冰之旅”的朝鲜副外相金桂冠3月5至6日在纽约与美国助理国务卿希尔就两国关系正常...    光明网  2007Q1
# 2     神秘，这是朝鲜留给外界的印象。 正因为神秘，一些国家的情报机构费尽心机，通过投放卫星、派遣侦...  中国经济网  2008Q3
# 1034  美国 国务卿 布林肯   抵达 韩国 。 看上去 似乎 礼仪性 道别 之 旅 防止 韩国 后...
# 1035  新华社 首尔   电 朝中社  报道 朝鲜 外务省 对外 政策 室长 谈话 谴责 美 韩 近...
# 1036  中新网   电 朝中社 报道 时间   朝鲜 外务省 对外 政策 室长 谈话 谴责 美 韩 ...
# 1037  中新网   电 孟湘君 特朗普 当选 新 任 美国 总统 后 意大利 以色列 先后 会面 。...
# 1038  新华社 北京   电 马卓言 孙素颖 针对 美 日 韩 外长 德国 慕尼黑 举行 会晤 联合...
#
# [1039 rows x 8 columns]

# %%
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer

# 전체 데이터셋에 대해 TF-IDF를 계산 (IDF는 전체 데이터셋에 대해 계산)
def calculate_keywords_by_quarter_with_global_idf(df, quarter_col="input_quarter", content_col="tokenized_content", top_n=10):
    keywords_by_quarter = {}

    # 1. 전체 데이터셋에 대해 TF-IDF 계산 (IDF는 전체 데이터셋을 기준으로 계산)
    # 전체 데이터셋을 기준으로 IDF 값을 계산합니다.
    vectorizer = TfidfVectorizer(max_features=1000)
    vectorizer.fit(df[content_col])  # 전체 데이터셋을 기준으로 IDF 값 계산

    # 2. 분기별로 데이터를 그룹화하여 처리 (분기별로 중요 키워드 추출)
    for quarter, group in df.groupby(quarter_col):
        # 3. 해당 분기 내의 기사를 대상으로 TF-IDF 계산 (IDF는 고정값 사용)
        tfidf_matrix_quarter = vectorizer.transform(group[content_col])  # 분기 내의 TF만 계산

        # 4. 각 분기 내에서 중요한 단어들을 추출하는 함수
        def get_top_keywords_for_quarter(tfidf_matrix_quarter, top_n=10):
            # 분기 내에서 단어들의 TF-IDF 점수를 합산
            sum_tfidf = np.sum(tfidf_matrix_quarter.toarray(), axis=0)  # 분기 내의 단어들의 TF-IDF 점수 합산
            top_indices = np.argsort(sum_tfidf)[::-1][:top_n]  # 중요도 높은 순으로 상위 단어 추출
            top_words = [(vectorizer.get_feature_names_out()[i], sum_tfidf[i]) for i in top_indices]  # (단어, 중요도 점수) 저장
            return ", ".join([f"{word} ({score:.4f})" for word, score in top_words])
        # 5. 해당 분기 내에서 중요한 키워드를 추출
        keywords_by_quarter[quarter] = get_top_keywords_for_quarter(tfidf_matrix_quarter)

    return keywords_by_quarter  # 결과로 분기별 키워드를 저장한 딕셔너리 반환

# 예시로 'input_quarter' 컬럼을 기준으로 그룹화하여 각 분기별로 키워드 계산
keywords_by_quarter = calculate_keywords_by_quarter_with_global_idf(df)

# 6. 모든 분기별 결과 출력
# 각 분기별로 추출된 중요 키워드를 출력합니다.
for quarter, keywords in keywords_by_quarter.items():
    print(f"\n✅ {quarter} 분기의 TF-IDF 키워드 상위 10개:")
    print(keywords)  # 각 분기별로 중요한 키워드 출력
# Out:
# ✅ 2006-2009Q 분기의 TF-IDF 키워드 상위 10개:
# 朝鲜 (4.0871), 发射 (2.2605), 导弹 (1.4539), 卫星 (1.3312), 美国 (1.1941), 安理会 (1.1397), 日本 (0.9838), 会谈 (0.9039), 韩国 (0.8200), 火箭 (0.7766)
#
# ✅ 2010Q1 분기의 TF-IDF 키워드 상위 10개:
# 演习 (0.4587), 参加 (0.3534), 联合 (0.3066), 军演 (0.2990), 海外 (0.2363), 军事 (0.2228), 机会 (0.2106), 美军 (0.1978), 军队 (0.1950), 韩国 (0.1683)
#
# ✅ 2010Q3 분기의 TF-IDF 키워드 상위 10개:
# 军演 (0.8929), 演习 (0.4647), 中国 (0.4639), 联合 (0.3880), 美国 (0.3081), 围堵 (0.2643), 最后 (0.2423), 22 (0.2176), 日本 (0.2162), 朝鲜 (0.2072)
#
# ✅ 2010Q4 분기의 TF-IDF 키워드 상위 10개:
# 朝鲜 (1.6255), 会谈 (1.5189), 外长 (1.2780), 日本 (1.2703), 美国 (0.9742), 报道 (0.9405), 中国 (0.8600), 半岛 (0.7367), 华盛顿 (0.6894), 军演 (0.6686)
#
# ✅ 2011Q1 분기의 TF-IDF 키워드 상위 10개:
# 朝鲜 (1.1499), 军演 (1.1050), 军事 (0.9017), 韩国 (0.7152), 协定 (0.6751), 日本 (0.6716), 美国 (0.6683), 签署 (0.5867), 半岛 (0.5493), 联合 (0.4833)
#
# ✅ 2011Q3 분기의 TF-IDF 키워드 상위 10개:
# 首脑 (0.3263), 问题 (0.2827), 李明博 (0.2402), 会谈 (0.2322), 独岛 (0.2285), 提及 (0.2164), 达成 (0.2108), 敏感 (0.1993), 共识 (0.1847), 关系 (0.1796)
#
# ✅ 2011Q4 분기의 TF-IDF 키워드 상위 10개:
# 高官 (0.3449), 签署 (0.3439), 重启 (0.3100), 报道 (0.3076), 对话 (0.3032), 演讲 (0.2725), 环球网 (0.2673), 问题 (0.2632), 磋商 (0.2612), 会谈 (0.2450)
#
# ✅ 2012Q1 분기의 TF-IDF 키워드 상위 10개:
# 朝鲜 (1.8852), 卫星 (1.5435), 发射 (1.5362), 南海 (0.7767), 美国 (0.6388), 拦截 (0.5215), 时报 (0.5166), 火箭 (0.4955), 环球 (0.4143), 日本 (0.4136)
#
# ✅ 2012Q2 분기의 TF-IDF 키워드 상위 10개:
# 军演 (5.1021), 演习 (2.6336), 朝鲜 (2.4960), 联合 (2.4700), 海上 (2.4313), 韩国 (2.2559), 海军 (1.9421), 美国 (1.8061), 日本 (1.7458), 举行 (1.6338)
#
# ✅ 2012Q3 분기의 TF-IDF 키워드 상위 10개:
# 日本 (2.1640), 中国 (1.9508), 美国 (1.8896), 韩国 (1.1372), 钓鱼岛 (1.0162), 问题 (0.9967), 独岛 (0.9940), 领土 (0.8536), 协定 (0.7438), 奥巴马 (0.6897)
#
# ✅ 2012Q4 분기의 TF-IDF 키워드 상위 10개:
# 发射 (3.8860), 朝鲜 (3.6462), 卫星 (3.1231), 火箭 (2.2256), 美国 (1.5155), 日本 (1.3772), 问题 (1.0162), 韩国 (0.9010), 安理会 (0.8326), 会谈 (0.7998)
#
# ✅ 2013Q1 분기의 TF-IDF 키워드 상위 10개:
# 朝鲜 (5.4761), 试验 (4.4552), 韩国 (1.8791), 日本 (1.8356), 中国 (1.6016), 进行 (1.5221), 美国 (1.5086), 安倍 (1.1592), 核武器 (1.0885), 导弹 (1.0395)
#
# ✅ 2013Q2 분기의 TF-IDF 키워드 상위 10개:
# 朝鲜 
분기의 TF-IDF 키워드 상위 10개:
# 朝鲜 (9.4737), 美国 (5.2479), 韩国 (4.8972), 试验 (4.1312), 发射 (4.1114), 制裁 (3.8616), 日本 (3.5337), 中国 (3.4944), 问题 (3.2538), 萨德 (3.0746)
#
# ✅ 2016Q2 분기의 TF-IDF 키워드 상위 10개:
# 导弹 (3.0047), 朝鲜 (2.5635), 美国 (2.1671), 防御 (1.8988), 系统 (1.7865), 军演 (1.7263), 联合 (1.4770), 韩国 (1.3860), 弹道 (1.2968), 演习 (1.2506)
#
# ✅ 2016Q3 분기의 TF-IDF 키워드 상위 10개:
# 萨德 (20.1397), 部署 (10.7611), 系统 (10.0645), 韩国 (7.0883), 反导 (7.0555), 美国 (7.0173), 中国 (5.9420), 朝鲜 (5.5888), 战略 (4.5349), 导弹 (4.3588)
#
# ✅ 2016Q4 분기의 TF-IDF 키워드 상위 10개:
# 协定 (7.6568), 情报 (5.2332), 军事 (4.5684), 签署 (4.5390), 韩国 (4.5147), 保护 (2.9826), 朴槿惠 (2.7350), 朝鲜 (2.6436), 日本 (2.3564), 萨德 (2.2094)
#
# ✅ 2017Q1 분기의 TF-IDF 키워드 상위 10개:
# 特朗普 (6.6538), 美国 (5.1847), 马蒂斯 (4.7550), 朝鲜 (4.5543), 中国 (3.9378), 韩国 (3.5126), 日本 (3.0827), 问题 (2.6105), 导弹 (2.5254), 关系 (2.4204)
#
# ✅ 2017Q2 분기의 TF-IDF 키워드 상위 10개:
# 朝鲜 (3.5676), 韩国 (2.8392), 导弹 (2.7289), 日本 (2.2692), 美国 (2.0239), 演习 (1.5584), 慰安妇 (1.5045), 问题 (1.2811), 航母 (1.2396), 反潜 (1.1796)
#
# ✅ 2017Q3 분기의 TF-IDF 키워드 상위 10개:
# 朝鲜 (3.6021), 导弹 (2.5292), 安理会 (2.0396), 试射 (1.9609), 声明 (1.6237), 决议 (1.6022), 发射 (1.5077), 美国 (1.4920), 特朗普 (1.4281), 联合国 (1.3982)
#
# ✅ 2017Q4 분기의 TF-IDF 키워드 상위 10개:
# 演习 (1.9584), 朝鲜 (1.3066), 韩国 (1.2838), 联合 (1.1777), 导弹 (1.1328), 美军 (0.9688), 半岛 (0.7995), 慰安妇 (0.7944), 预警 (0.7723), 同盟 (0.7674)
#
# ✅ 2018Q1 분기의 TF-IDF 키워드 상위 10개:
# 会谈 (1.3083), 日本 (1.2181), 朝鲜 (1.2105), 半岛 (1.1766), 文在寅 (0.9858), 美国 (0.9459), 韩国 (0.9072), 问题 (0.8466), 举行 (0.8279), 中国 (0.8134)
#
# ✅ 2018Q2 분기의 TF-IDF 키워드 상위 10개:
# 会谈 (0.8288), 安倍 (0.7689), 外长 (0.5777), 日本 (0.4526), 防长 (0.4145), 首脑 (0.3904), 内阁 (0.3903), 举行 (0.3649), 报道 (0.3504), 今后 (0.2815)
#
# ✅ 2018Q3 분기의 TF-IDF 키워드 상위 10개:
# 外长 (0.9038), 三角 (0.6098), 会谈 (0.5913), 无核化 (0.4776), 朝鲜 (0.4766), 东京 (0.4325), 国务卿 (0.3995), 具体 (0.3799), 举行 (0.3472), 访问 (0.3432)
#
# ✅ 2018Q4 분기의 TF-IDF 키워드 상위 10개:
# 慰安妇 (0.6553), 协议 (0.3326), 韩国 (0.2020), 问题 (0.1987), 解决 (0.1700), 受害者 (0.1600), 日方 (0.1596), 彻底 (0.1414), 民众 (0.1359), 日本 (0.1132)
#
# ✅ 2019Q1 분기의 TF-IDF 키워드 상위 10개:
# 日本 (1.3350), 特朗普 (1.1293), 会谈 (1.0133), 雷达 (1.0120), 道歉 (0.9494), 韩国 (0.8964), 朝鲜 (0.8852), 美国 (0.8158), 磋商 (0.6942), 第二 (0.6442)
#
# ✅ 2019Q2 분기의 TF-IDF 키워드 상위 10개:
# 美国 (0.6700), 产品 (0.6484), 雷达 (0.6285), 飞机 (0.5257), 印太 (0.4362), 日本 (0.4272), 关系 (0.4255), 朝鲜 (0.4205), 韩国 (0.4052), 驱逐舰 (0.3919)
#
# ✅ 2019Q3 분기의 TF-IDF 키워드 상위 10개:
# 韩国 (8.2043), 日本 (6.5814), 美国 (5.6867), 协定 (5.2927), 出口 (4.7296), 贸易 (4.7276), 情报 (3.5872), 关系 (3.4909), 韩方 (3.3685), 管制 (2.9967)
#
# ✅ 2019Q4 분기의 TF-IDF 키워드 상위 10개:
# 协定 (4.3340), 韩国 (2.5802), 情报 (1.7540), 美国 (1.7521), 日本 (1.6073), 保护 (1.5742), 军事 (1.5514), 关系 (1.3934), 贸易 (0.9987), 问题 (0.9337)
#
# ✅ 2020Q1 분기의 TF-IDF 키워드 상위 10개:
# 韩国 (1.3117), 美国 (0.9697), 中东 (0.9266), 日本 (0.7696), 朝鲜 (0.7422), 韩方 (0.7165), 会谈 (0.6824), 谈判 (0.6189), 大使 (0.5607), 报道 (0.5465)
#
# ✅ 2020Q3 분기의 TF-IDF 키워드 상위 10개:
# 战机 (0.7135), 35 (0.6886), 协定 (0.6710), 航母 (0.6505), 韩国 (0.5966), 印太 (0.5597), 地区 (0.5204), 日本 (0.4967), 美国 (0.3990), 军事 (0.3872)
#
# ✅ 2020Q4 분기의 TF-IDF 키워드 상위 10개:
# 拜登 (0.5756), 菅义伟 (0.3559), 印太 (0.1785), 条约 (0.1699), 韩国 (0.1629), 表态 (0.1452), 同盟 (0.1435), 日本 (0.1425), 文在寅 (0.1332), 关键 (0.1322)
#
# ✅ 2021Q1 분기의 TF-IDF 키워드 상위 10개:
# 白皮书 (1.3947), 韩国 (1.3110), 拜登 (1.0895), 日本 (1.0158), 美国 (0.8241), 关系 (0.8048), 航母 (0.7623), 矛盾 (0.6590), 奥斯汀 (0.6420), 印太 (0.6317)
#
# ✅ 2021Q2 분기의 TF-IDF 키워드 상위 10개:
# 半导体 (2.1520), 美国 (1.8036), 拜登 (1.5651), 韩国 (1.4908), 会谈 (1.2749), 朝鲜 (1.2661), 举行 (1.1927), 空军 (1.0855), 报道 (1.0306), 日本 (1.0237)
#
# ✅ 2021Q3 분기의 TF-IDF 키워드 상위 10개:
# 巡航 (1.1707), 导弹 (0.9775), 韩国 (0.8605), 朝鲜 (0.6414), 东京 (0.5882), 文在寅 (0.5408), 远程 (0.5160), 试射 (0.4617), 矛盾 (0.4394), 关系 (0.4069)
#
# ✅ 2021Q4 분기의 TF-IDF 키워드 상위 10개:
# 记者会 (1.3069), 独岛 (1.0887), 日方 (0.9568), 韩国 (0.9099), 日本 (0.8449), 韩方 (0.7119), 问题 (0.6821), 岛屿 (0.6633), 争议 (0.6151), 会谈 (0.5381)
#
# ✅ 2024Q4 분기의 TF-IDF 키워드 상위 10개:
# 演习 (3.2515), 韩国 (2.9952), 美国 (1.7599), 联合 (1.7465), 尹锡悦 (1.6767), 朝鲜 (1.6724), 战斗机 (1.5627), 日本 (1.5000), 作战 (1.4555), 中国 (1.3142)
#
# ✅ 2025Q1 분기의 TF-IDF 키워드 상위 10개:
# 谈话 (1.1296), 尹锡悦 (0.8822), 特朗普 (0.8531), 行为 (0.5513), 朝方 (0.5439), 外交 (0.5401), 地区 (0.5239), 美国 (0.5177), 韩国 (0.5035), 联合 (0.4974)

# %%
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer

# 전체 데이터셋에 대해 TF-IDF를 계산 (IDF는 전체 데이터셋에 대해 계산)
def calculate_keywords_by_quarter_with_global_idf(df, quarter_col="input_quarter", content_col="tokenized_content", top_n=10):
    keywords_by_quarter = {}

    # 1. 전체 데이터셋에 대해 TF-IDF를 계산 (IDF는 전체 데이터셋에 대해 계산)
    vectorizer = TfidfVectorizer(max_features=1000)
    vectorizer.fit(df[content_col])  # 전체 데이터셋을 기준으로 IDF 값 계산
    feature_names = vectorizer.get_feature_names_out()  # 전체 데이터에서 추출된 단어 리스트
    num_features = len(feature_names)  # 단어 수 확인

    # 2. 분기별로 데이터를 그룹화하여 처리 (분기별로 중요 키워드 추출)
    results = {}  # 분기별 키워드와 문서 개수를 저장할 딕셔너리

    for quarter, group in df.groupby(quarter_col):
        total_articles_in_quarter = len(group)  # 해당 분기의 전체 기사 수

        # 3. 해당 분기 내의 기사를 대상으로 TF 계산 (IDF는 고정값 사용)
        tfidf_matrix_quarter = vectorizer.transform(group[content_col])  # 분기 내의 TF만 계산

        # 4. 각 분기 내에서 중요한 단어들을 추출하는 함수
        def get_top_keywords_for_quarter(tfidf_matrix_quarter, top_n=10):
            if tfidf_matrix_quarter.shape[0] == 0:  # 분기에 데이터가 없을 경우 예외 처리
                return []

            # 분기 내에서 단어들의 TF-IDF 점수를 합산
            sum_tfidf = np.sum(tfidf_matrix_quarter.toarray(), axis=0)  # 분기 내의 단어들의 TF-IDF 점수 합산
            sum_tfidf_normalized = sum_tfidf / total_articles_in_quarter  # 문서 수로 정규화

            # top_n이 실제 단어 수보다 크지 않도록 제한
            actual_top_n = min(top_n, num_features, len(sum_tfidf_normalized))
            if actual_top_n == 0:
                return []

            # 중요도 높은 순으로 상위 단어 추출
            top_indices = np.argsort(sum_tfidf_normalized)[::-1][:actual_top_n]

            # TF 점수와 IDF 점수를 계산
            tf_scores = [sum_tfidf[i] for i in top_indices]
            idf_scores = [vectorizer.idf_[i] for i in top_indices]

            # 예외 처리: 인덱스가 범위를 초과하지 않도록
            top_words = []
            for i in top_indices:
                if i < num_features:  # 인덱스 범위 초과 방지
                    top_words.append((feature_names[i], tf_scores[top_indices.tolist().index(i)], idf_scores[top_indices.tolist().index(i)], sum_tfidf_normalized[i]))

            return top_words  # (단어, TF 점수, IDF 점수, TF-IDF 점수) 리스트 반환

        # 5. 해당 분기 내에서 중요한 키워드를 추출
        keywords_by_quarter = get_top_keywords_for_quarter(tfidf_matrix_quarter)

        # 6. 결과 저장 (분기명, 문서 개수, 키워드 목록)
        results[quarter] = {"document_count": total_articles_in_quarter, "keywords": keywords_by_quarter}

    return results  # 결과로 분기별 키워드와 문서 개수를 저장한 딕셔너리 반환

# 예시로 'input_quarter' 컬럼을 기준으로 그룹화하여 각 분기별로 키워드 계산
results = calculate_keywords_by_quarter_with_global_idf(df)

# 7. 모든 분기별 결과 출력
# 각 분기별로 추출된 중요 키워드와 TF, IDF 점수, 문서 개수를 출력합니다.
for quarter, data in results.items():
    document_count = data["document_count"]
    keywords = data["keywords"]

    print(f"\n <{quarter} 분기> : {document_count}개")
    print("단어", "TF 점수", "IDF 점수", "TF-IDF 점수")  # 제목 출력
    for word, tf_score, idf_score, tfidf_score in keywords:
        print(f"{word} ({tf_score:.4f}) ({idf_score:.4f}) ({tfidf_score:.4f})")  # 각 분기별 키워드 및 점수 출력
# Out:
#  <2006-2009Q 분기> : 14개
# 단어 TF 점수 IDF 점수 TF-IDF 점수
# 朝鲜 (4.0871) (1.3608) (0.2919)
# 发射 (2.2605) (2.5089) (0.1615)
# 导弹 (1.4539) (1.8092) (0.1038)
# 卫星 (1.3312) (3.1934) (0.0951)
# 美国 (1.1941) (1.0635) (0.0853)
# 安理会 (1.1397) (3.2741) (0.0814)
# 日本 (0.9838) (1.1535) (0.0703)
# 会谈 (0.9039) (1.9406) (0.0646)
# 韩国 (0.8200) (1.1435) (0.0586)
# 火箭 (0.7766) (3.8865) (0.0555)
#
#  <2010Q1 분기> : 1개
# 단어 TF 점수 IDF 점수 TF-IDF 점수
# 演习 (0.4587) (2.2267) (0.4587)
# 参加 (0.3534) (2.4018) (0.3534)
# 联合 (0.3066) (1.7364) (0.3066)
# 军演 (0.2990) (2.5398) (0.2990)
# 海外 (0.2363) (4.0152) (0.2363)
# 军事 (0.2228) (1.5140) (0.2228)
# 机会 (0.2106) (3.5775) (0.2106)
# 美军 (0.1978) (2.2399) (0.1978)
# 军队 (0.1950) (3.3122) (0.1950)
# 韩国 (0.1683) (1.1435) (0.1683)
#
#  <2010Q3 분기> : 2개
# 단어 TF 점수 IDF 점수 TF-IDF 점수
# 军演 (0.8929) (2.5398) (0.4464)
# 演习 (0.4647) (2.2267) (0.2323)
# 中国 (0.4639) (1.6262) (0.2319)
# 联合 (0.3880) (1.7364) (0.1940)
# 美国 (0.3081) (1.0635) (0.1541)
# 围堵 (0.2643) (4.0152) (0.1322)
# 最后 (0.2423) (3.2108) (0.1211)
# 22 (0.2176) (4.0152) (0.1088)
# 日本 (0.2162) (1.1535) (0.1081)
# 朝鲜 (0.2072) (1.3608) (0.1036)
#
#  <2010Q4 분기> : 8개
# 단어 TF 점수 IDF 점수 TF-IDF 점수
# 朝鲜 (1.6255) (1.3608) (0.2032)
# 会谈 (1.5189) (1.9406) (0.1899)
# 外长 (1.2780) (2.8907) (0.1598)
# 日本 (1.2703) (1.1535) (0.1588)
# 美国 (0.9742) (1.0635) (0.1218)
# 报道 (0.9405) (1.3691) (0.1176)
# 中国 (0.8600) (1.6262) (0.1075)
# 半岛 (0.7367) (1.7690) (0.0921)
# 华盛顿 (0.6894) (2.4457) (0.0862)
# 军演 (0.6686) (2.5398) (0.0836)
#
#  <2011Q1 분기> : 6개
# 단어 TF 점수 IDF 점수 TF-IDF 점수
#

# 단어 TF 점수 IDF 점수 TF-IDF 점수
# 美国 (4.8428) (1.0635) (0.1030)
# 日本 (4.6236) (1.1535) (0.0984)
# 合作 (4.5073) (1.4278) (0.0959)
# 中国 (3.8059) (1.6262) (0.0810)
# 联合 (3.5981) (1.7364) (0.0766)
# 地区 (3.3214) (1.5237) (0.0707)
# 海上 (3.0214) (2.6338) (0.0643)
# 安全 (2.9472) (1.5173) (0.0627)
# 航母 (2.9066) (3.2556) (0.0618)
# 演习 (2.8290) (2.2267) (0.0602)
#
#  <2024Q3 분기> : 22개
# 단어 TF 점수 IDF 점수 TF-IDF 점수
# 美国 (3.0258) (1.0635) (0.1375)
# 中国 (2.5782) (1.6262) (0.1172)
# 地区 (2.2546) (1.5237) (0.1025)
# 司令部 (2.1350) (3.3220) (0.0970)
# 美军 (1.9725) (2.2399) (0.0897)
# 合作 (1.8815) (1.4278) (0.0855)
# 日本 (1.7816) (1.1535) (0.0810)
# 印太 (1.6923) (2.6843) (0.0769)
# 安全 (1.5978) (1.5173) (0.0726)
# 亚太 (1.5226) (2.0335) (0.0692)
#
#  <2024Q4 분기> : 24개
# 단어 TF 점수 IDF 점수 TF-IDF 점수
# 演习 (3.2515) (2.2267) (0.1355)
# 韩国 (2.9952) (1.1435) (0.1248)
# 美国 (1.7599) (1.0635) (0.0733)
# 联合 (1.7465) (1.7364) (0.0728)
# 尹锡悦 (1.6767) (2.9498) (0.0699)
# 朝鲜 (1.6724) (1.3608) (0.0697)
# 战斗机 (1.5627) (3.7423) (0.0651)
# 日本 (1.5000) (1.1535) (0.0625)
# 作战 (1.4555) (2.7879) (0.0606)
# 中国 (1.3142) (1.6262) (0.0548)
#
#  <2025Q1 분기> : 6개
# 단어 TF 점수 IDF 점수 TF-IDF 점수
# 谈话 (1.1296) (3.8694) (0.1883)
# 尹锡悦 (0.8822) (2.9498) (0.1470)
# 特朗普 (0.8531) (3.1187) (0.1422)
# 行为 (0.5513) (2.6537) (0.0919)
# 朝方 (0.5439) (3.3418) (0.0907)
# 外交 (0.5401) (1.8136) (0.0900)
# 地区 (0.5239) (1.5237) (0.0873)
# 美国 (0.5177) (1.0635) (0.0863)
# 韩国 (0.5035) (1.1435) (0.0839)
# 联合 (0.4974) (1.7364) (0.0829)

# %%
# import pandas as pd
# import numpy as np
# from sklearn.feature_extraction.text import TfidfVectorizer
#
# # 전체 데이터셋에 대해 TF-IDF를 계산 (IDF는 전체 데이터셋에 대해 계산)
# def calculate_keywords_by_quarter_with_article_ratio(df, quarter_col="input_quarter", content_col="tokenized_content", top_n=10):
#     keywords_by_quarter = {}
#
#     # 1. NaN 또는 None 값을 빈 문자열로 변환하여 TfidfVectorizer가 처리할 수 있도록 함
#     df[content_col] = df[content_col].fillna("")  # NaN 또는 None 값을 빈 문자열로 처리
#
#     # 2. 전체 데이터셋에 대해 TF-IDF 계산 (IDF는 전체 데이터셋을 기준으로 계산)
#     vectorizer = TfidfVectorizer(max_features=1000)
#     tfidf_matrix = vectorizer.fit_transform(df[content_col])  # 전체 데이터셋을 기준으로 TF-IDF 계산
#     feature_names = vectorizer.get_feature_names_out()  # 계산된 단어 리스트
#
#     # 3. 분기별로 데이터를 그룹화하여 처리 (분기별로 중요 키워드 추출)
#     for quarter, group in df.groupby(quarter_col):
#         # 4. 각 분기 내에서 등장한 단어의 등장한 기사 수를 계산
#         # 5. 각 분기의 기사 수
#         total_articles_in_quarter = len(group)
#
#         # 6. 각 단어가 등장한 기사 수 계산
#         term_frequencies = np.zeros(len(feature_names))  # 각 단어가 등장한 기사 수를 저장
#
#         for idx, row in group.iterrows():
#             # 해당 기사에서 등장한 단어를 찾음
#             words_in_article = set(row[content_col].split())  # 해당 기사의 단어 리스트 (set으로 중복 제거)
#             for word in words_in_article:
#                 if word in feature_names:
#                     word_idx = feature_names.tolist().index(word)  # 해당 단어의 인덱스를 찾음
#                     term_frequencies[word_idx] += 1  # 해당 단어가 등장한 기사 수를 증가시킴
#
#         # 7. 등장한 기사 수 / 전체 기사 수로 비율 계산 (단어의 중요도 비율)
#         term_frequencies_ratio = term_frequencies / total_articles_in_quarter
#
#         # 8. 비율 계산: 각 단어의 비율 (전체 문서 내에서의 단어의 중요도에 대한 상대적인 비율)
#         top_indices = np.argsort(term_frequencies_ratio)[::-1][:top_n]  # 중요도 높은 순으로 상위 단어 추출
#         top_words = [(feature_names[i], term_frequencies_ratio[i]) for i in top_indices]  # (단어, 중요도 점수) 저장
#
#         # 9. 해당 분기 내에서 중요한 키워드를 추출
#         keywords_by_quarter[quarter] = ", ".join([f"{word} ({score:.4f})" for word, score in top_words])
#
#     return keywords_by_quarter  # 결과로 분기별 키워드를 저장한 딕셔너리 반환
#
# # 예시로 'input_quarter' 컬럼을 기준으로 그룹화하여 각 분기별로 키워드 계산
# keywords_by_quarter = calculate_keywords_by_quarter_with_article_ratio(df)
#
# # 10. 모든 분기별 결과 출력
# # 각 분기별로 추출된 중요 키워드를 출력합니다.
# for quarter, keywords in keywords_by_quarter.items():
#     print(f"\n✅ {quarter} 분기의 TF-IDF 키워드 상위 10개:")
#     print(keywords)  # 각 분기별로 중요한 키워드 출력
# Out:
# ✅ 2006-2009Q 분기의 TF-IDF 키워드 상위 10개:
# 韩国 (0.8571), 美国 (0.8571), 朝鲜 (0.8571), 日本 (0.7857), 报道 (0.7143), 问题 (0.6429), 紧张 (0.5714), 进行 (0.5714), 发射 (0.5714), 安全 (0.5000)
#
# ✅ 2010Q1 분기의 TF-IDF 키워드 상위 10개:
# 方面 (1.0000), 韩国 (1.0000), 韩军 (1.0000), 积极 (1.0000), 进行 (1.0000), 环球网 (1.0000), 正在 (1.0000), 方案 (1.0000), 海外 (1.0000), 报道 (1.0000)
#
# ✅ 2010Q3 분기의 TF-IDF 키워드 상위 10개:
# 22 (1.0000), 防卫 (1.0000), 韩国 (1.0000), 之后 (1.0000), 参加 (1.0000), 反潜 (1.0000), 军事 (1.0000), 军演 (1.0000), 出现 (1.0000), 关系 (1.0000)
#
# ✅ 2010Q4 분기의 TF-IDF 키워드 상위 10개:
# 朝鲜 (1.0000), 报道 (1.0000), 日本 (1.0000), 美国 (1.0000), 会谈 (1.0000), 进行 (0.7500), 问题 (0.7500), 环球网 (0.7500), 外长 (0.7500), 局势 (0.7500)
#
# ✅ 2011Q1 분기의 TF-IDF 키워드 상위 10개:
# 韩国 (1.0000), 军事 (1.0000), 美国 (1.0000), 朝鲜 (1.0000), 半岛 (1.0000), 同盟 (0.8333), 进行 (0.8333), 规模 (0.8333), 日本 (0.8333), 局势 (0.8333)
#
# ✅ 2011Q3 분기의 TF-IDF 키워드 상위 10개:
# 访问 (1.0000), 方面 (1.0000), 首脑 (1.0000), 方案 (1.0000), 赔偿 (1.0000), 竹岛 (1.0000), 有关 (1.0000), 美国 (1.0000), 相互 (1.0000), 首相 (1.0000)
#
# ✅ 2011Q4 분기의 TF-IDF 키워드 상위 10개:
# 重启 (1.0000), 进行 (1.0000), 韩国 (1.0000), 磋商 (1.0000), 日本 (1.0000), 问题 (1.0000), 报道 (1.0000), 立场 (1.0000), 环球网 (1.0000), 国际 (1.0000)
#
# ✅ 2012Q1 분기의 TF-IDF 키워드 상위 10개:
# 美国 (1.0000), 朝鲜 (0.8333), 和平 (0.8333), 韩国 (0.8333), 中国 (0.8333), 威胁 (0.6667), 发射 (0.6667), 行为 (0.6667), 安全 (0.6667), 日本 (0.6667)
#
# ✅ 2012Q2 분기의 TF-IDF 키워드 상위 10개:
# 美国 (1.0000), 日本 (1.0000), 举行 (0.9412), 朝鲜 (0.9412), 韩国 (0.9412), 半岛 (0.8235), 海上 (0.8235), 军演 (0.8235), 联合 (0.8235), 报道 (0.8235)
#
# ✅ 2012Q3 분기의 TF-IDF 키워드 상위 10개:
# 中国 (1.0000), 日本 (1.0000), 问题 (1.0000), 美国 (1.0000), 举行 (0.9000), 关系 (0.9000), 国家 (0.9000), 成为 (0.8000), 没有 (0.8000), 合作 (0.8000)
#
# ✅ 2012Q4 분기의 TF-IDF 키워드 상위 10개:
# 日本 (1.0000), 美国 (1.0000), 韩国 (0.9333), 问题 (0.8667), 进行 (0.8667), 朝鲜 (0.8000), 报道 (0.7333), 半岛 (0.6667), 发射 (0.6667), 导弹 (0.6000)
#
# ✅ 2013Q1 분기의 TF-IDF 키워드 상위 10개:
# 朝鲜 (0.9444), 美国 (0.8889), 韩国 (0.8889), 日本 (0.8333), 进行 (0.7778), 问题 (0.7222), 中国 (0.7222), 试验 (0.7222), 报道 (0.6111), 有关 (0.6111)
#
# ✅ 2013Q2 분기의 TF-IDF 키워드 상위 10개:
# 韩国 (0.9722), 朝鲜 (0.9167), 美国 (0.9167), 日本 (0.8889), 进行 (0.6389), 半岛 (0.6389), 报道 (0.6389), 举行 (0.5833), 问题 (0.5833), 导弹 (0.5278)
#
# ✅ 2013Q3 분기의 TF-IDF 키워드 상위 10개:
# 日本 (1.0000), 报道 (1.0000), 美国 (1.0000), 访问 (0.7500), 中国 (0.7500), 目标 (0.7500), 韩国 (0.7500), 亚洲 (0.5000), 不过 (0.5000), 人员 (0.5000)
#
# ✅ 2013Q4 분기의 TF-IDF 키워드 상위 10개:
# 报道 (1.0000), 美国 (0.9286), 朝鲜 (0.7857), 韩国 (0.7857), 日本 (0.7143), 问题 (0.6429), 进行 (0.6429), 关系 (0.6429), 中国 (0.5714), 要求 (0.5714)
#
# ✅ 2014Q1 분기의 TF-IDF 키워드 상위 10개:
# 日本 (1.0000), 美国 (0.9643), 问题 (0.9286), 韩国 (0.9286), 安倍 (0.8571), 报道 (0.8571), 关系 (0.8571), 安倍晋三 (0.8214), 总统 (0.8214), 会谈 (0.7857)
#
# ✅ 2014Q2 분기의 TF-IDF 키워드 상위 10개:
# 韩国 (0.9333), 报道 (0.9333), 美国 (0.9333), 日本 (0.8667), 朝鲜 (0.8667), 举行 (0.7333), 主要 (0.7333), 威胁 (0.6667), 导弹 (0.6667), 合作 (0.6667)
#
# ✅ 2014Q3 분기의 TF-IDF 키워드 상위 10개:
# 日本 (0.9091), 朝鲜 (0.9091), 美国 (0.8182), 韩国 (0.7273), 导弹 (0.7273), 举行 (0.7273), 联合 (0.6364), 报道 (0.6364), 军事 (0.6364), 安倍 (0.5455)
#
# ✅ 2014Q4 분기의 TF-IDF 키워드 상위 10개:
# 导弹 (1.0000), 韩国 (1.0000), 美国 (1.0000), 朝鲜 (1.0000), 军事 (0.9444), 日本 (0.8889), 报道 (0.8889), 情报 (0.8889), 签署 (0.8889), 协议 (0.8333)
#
# ✅ 2015Q1 분기의 TF-IDF 키워드 상위 10개:
# 问题 (1.0000), 美国 (1.0000), 日本 (0.9167), 韩国 (0.9167), 半岛 (0.8333), 朝鲜 (0.8333), 关系 (0.8333), 地区 (0.7500), 进行 (0.7500), 历史 (0.6667)
#
# ✅ 2015Q2 분기의 TF-IDF 키워드 상위 10개:
# 日本 (0.9615), 问题 (0.9231), 韩国 (0.9231), 美国 (0.9231), 关系 (0.8077), 合作 (0.6923), 外交 (0.6538), 朝鲜 (0.6538), 访问 (0.6538), 重要 (0.6154)
#
# ✅ 2015Q3 분기의 TF-IDF 키워드 상위 10개:
# 韩国 (1.0000), 美国 (1.0000), 朝鲜 (0.8889), 日本 (0.8889), 报道 (0.8889), 举行 (0.6667), 国际 (0.6667), 关系 (0.6667), 问题 (0.6667), 合作 (0.6667)
#
# ✅ 2015Q4 분기의 TF-IDF 키워드 상위 10개:
# 问题 (1.0000), 韩国 (0.9091), 解决 (0.8182), 美国 (0.8182), 日本 (0.8182), 报道 (0.7727), 关系 (0.7727), 合作 (0.7273), 会谈 (0.7273), 朝鲜 (0.6818)
#
# ✅ 2016Q1 분기의 TF-IDF 키워드 상위 10개:
# 美国 (0.9773), 韩国 (0.9091), 朝鲜 (0.9091), 日本 (0.8182), 问题 (0.7500), 安全 (0.7045), 国家 (0.6818), 报道 (0.6818), 进行 (0.6818), 中国 (0.6591)
#
# ✅ 2016Q2 분기의 TF-IDF 키워드 상위 10개:
# 美国 (0.9474), 日本 (0.7895), 韩国 (0.7895), 报道 (0.7368), 朝鲜 (0.7368), 军事 (0.6842), 进行 (0.6316), 威胁 (0.5789), 导弹 (0.5789), 举行 (0.5789)
#
# ✅ 2016Q3 분기의 TF-IDF 키워드 상위 10개:
# 韩国 (0.9636), 美国 (0.9636), 朝鲜 (0.9273), 问题 (0.9091), 萨德 (0.8727), 部署 (0.8545), 中国 (0.8182), 军事 (0.8182), 系统 (0.8182), 地区 (0.8182)
#
# ✅ 2016Q4 분기의 TF-IDF 키워드 상위 10개:
# 韩国 (1.0000), 美国 (1.0000), 日本 (0.9583), 朝鲜 (0.9583), 问题 (0.9583), 军事 (0.8750), 合作 (0.8750), 反对 (0.8333), 安全 (0.7917), 导弹 (0.7917)
#
# ✅ 2017Q1 분기의 TF-IDF 키워드 상위 10개:
# 美国 (0.9730), 韩国 (0.8649), 日本 (0.8108), 中国 (0.8108), 朝鲜 (0.8108), 问题 (0.7568), 特朗普 (0.7027), 地区 (0.6486), 军事 (0.6486), 政策 (0.6486)
#
# ✅ 2017Q2 분기의 TF-IDF 키워드 상위 10개:
# 韩国 (0.9524), 日本 (0.9048), 朝鲜 (0.8571), 美国 (0.8571), 问题 (0.7143), 进行 (0.7143), 导弹 (0.7143), 报道 (0.7143), 军事 (0.6667), 总统 (0.6190)
#
# ✅ 2017Q3 분기의 TF-IDF 키워드 상위 10개:
# 朝鲜 (1.0000), 日本 (0.9231), 美国 (0.9231), 威胁 (0.9231), 导弹 (0.9231), 韩国 (0.8462), 报道 (0.7692), 联合国 (0.7692), 国家 (0.7692), 发射 (0.6923)
#
# ✅ 2017Q4 분기의 TF-IDF 키워드 상위 10개:
# 韩国 (1.0000), 日本 (1.0000), 美国 (0.9000), 联合 (0.9000), 朝鲜 (0.9000), 军事 (0.8000), 半岛 (0.8000), 报道 (0.8000), 举行 (0.7000), 问题 (0.7000)
#
# ✅ 2018Q1 분기의 TF-IDF 키워드 상위 10개:
# 韩国 (0.9000), 美国 (0.9000), 日本 (0.9000), 朝鲜 (0.8000), 举行 (0.8000), 问题 (0.8000), 会谈 (0.8000), 合作 (0.7000), 继续 (0.7000), 进行 (0.7000)
#
# ✅ 2018Q2 분기의 TF-IDF 키워드 상위 10개:
# 举行 (1.0000), 韩国 (1.0000), 会谈 (1.0000), 朝鲜 (1.0000), 首脑 (1.0000), 报道 (1.0000), 日本 (1.0000), 亚洲 (0.6667), 东北亚 (0.6667), 今后 (0.6667)
#
# ✅ 2018Q3 분기의 TF-IDF 키워드 상위 10개:
# 无核化 (1.0000), 美国 (1.0000), 朝鲜 (1.0000), 韩国 (1.0000), 半岛 (1.0000), 举行 (1.0000), 东京 (1.0000), 机制 (0.6667), 首脑 (0.6667), 访问 (0.6667)
#
# ✅ 2018Q4 분기의 TF-IDF 키워드 상위 10개:
# 一致 (1.0000), 首相 (1.0000), 不过 (1.0000), 世界 (1.0000), 韩国 (1.0000), 2015年 (1.0000), 中国 (1.0000), 中心 (1.0000), 主任 (1.0000), 主导 (1.0000)
#
# ✅ 2019Q1 분기의 TF-IDF 키워드 상위 10개:
# 韩国 (0.9000), 美国 (0.9000), 进行 (0.9000), 日本 (0.9000), 朝鲜 (0.9000), 合作 (0.8000), 报道 (0.7000), 继续 (0.7000), 重要 (0.7000), 问题 (0.7000)
#
# ✅ 2019Q2 분기의 TF-IDF 키워드 상위 10개:
# 联合 (1.0000), 关系 (1.0000), 美国 (0.8333), 以来 (0.8333), 举行 (0.8333), 社会 (0.8333), 国际 (0.8333), 日本 (0.8333), 希望 (0.8333), 韩国 (0.8333)
#
# ✅ 2019Q3 분기의 TF-IDF 키워드 상위 10개:
# 韩国 (0.9744), 美国 (0.9744), 日本 (0.9487), 关系 (0.9487), 报道 (0.8462), 安全 (0.8462), 问题 (0.7692), 贸易 (0.7692), 双方 (0.7692), 举行 (0.7436)
#
# ✅ 2019Q4 분기의 TF-IDF 키워드 상위 10개:
# 美国 (1.0000), 韩国 (0.9333), 军事 (0.9333), 关系 (0.8667), 日本 (0.8667), 问题 (0.8667), 协定 (0.8000), 保护 (0.7333), 进行 (0.7333), 情报 (0.7333)
#
# ✅ 2020Q1 분기의 TF-IDF 키워드 상위 10개:
# 韩国 (1.0000), 报道 (1.0000), 日本 (1.0000), 美国 (1.0000), 要求 (1.0000), 总统 (0.8333), 韩方 (0.8333), 问题 (0.8333), 提出 (0.8333), 计划 (0.8333)
#
# ✅ 2020Q3 분기의 TF-IDF 키워드 상위 10개:
# 主要 (1.0000), 韩国 (1.0000), 问题 (1.0000), 日本 (1.0000), 进行 (1.0000), 影响 (1.0000), 地区 (1.0000), 因素 (1.0000), 美国 (1.0000), 军事 (1.0000)
#
# ✅ 2020Q4 분기의 TF-IDF 키워드 상위 10개:
# 政策 (1.0000), 政治 (1.0000), 安保 (1.0000), 舆论 (1.0000), 如此 (1.0000), 奥巴马 (1.0000), 大选 (1.0000), 高度 (1.0000), 自由 (1.0000), 首相 (1.0000)
#
# ✅ 2021Q1 분기의 TF-IDF 키워드 상위 10개:
# 美国 (1.0000), 韩国 (1.0000), 日本 (0.8750), 地区 (0.8750), 安全 (0.8750), 方面 (0.8750), 报道 (0.8750), 应对 (0.7500), 进行 (0.7500), 盟友 (0.7500)
#
# ✅ 2021Q2 분기의 TF-IDF 키워드 상위 10개:
# 美国 (1.0000), 举行 (0.9231), 韩国 (0.9231), 拜登 (0.8462), 问题 (0.8462), 会谈 (0.8462), 合作 (0.8462), 日本 (0.8462), 报道 (0.8462), 进行 (0.6923)
#
# ✅ 2021Q3 분기의 TF-IDF 키워드 상위 10개:
# 举行 (1.0000), 问题 (1.0000), 日本 (1.0000), 朝鲜 (1.0000), 总统 (1.0000), 美国 (1.0000), 韩国 (1.0000), 半岛 (1.0000), 方面 (0.8000), 以来 (0.8000)
#
# ✅ 2021Q4 분기의 TF-IDF 키워드 상위 10개:
# 日本 (1.0000), 韩国 (1.0000), 独岛 (0.8333), 日方 (0.8333), 报道 (0.8333), 强烈 (0.8333), 外交部 (0.8333), 联合 (0.8333), 问题 (0.8333), 举行 (0.8333)
#
# ✅ 2022Q1 분기의 TF-IDF 키워드 상위 10개:
# 美国 (1.0000), 进行 (0.8000), 力量 (0.8000), 威胁 (0.8000), 地区 (0.8000), 加强 (0.8000), 合作 (0.8000), 国务卿 (0.8000), 问题 (0.8000), 关系 (0.8000)
#
# ✅ 2022Q2 분기의 TF-IDF 키워드 상위 10개:
# 举行 (1.0000), 安全 (1.0000), 地区 (1.0000), 美国 (1.0000), 问题 (0.8750), 韩国 (0.8750), 关系 (0.8750), 印太 (0.8750), 尹锡悦 (0.8750), 国际 (0.8750)
#
# ✅ 2022Q3 분기의 TF-IDF 키워드 상위 10개:
# 美国 (1.0000), 韩国 (0.8667), 以来 (0.7333), 日本 (0.7333), 报道 (0.6667), 国家 (0.6667), 军事 (0.6667), 联合 (0.6667), 紧张 (0.6000), 外交 (0.6000)
#
# ✅ 2022Q4 분기의 TF-IDF 키워드 상위 10개:
# 美国 (0.9167), 韩国 (0.8333), 合作 (0.7500), 问题 (0.7500), 报道 (0.7500), 国家 (0.7500), 日本 (0.6667), 应对 (0.6667), 举行 (0.6667), 演习 (0.6667)
#
# ✅ 2023Q1 분기의 TF-IDF 키워드 상위 10개:
# 日本 (1.0000), 美国 (0.8929), 关系 (0.8214), 问题 (0.8214), 举行 (0.7500), 战略 (0.7500), 发展 (0.7500), 韩国 (0.7500), 地区 (0.7500), 经济 (0.7500)
#
# ✅ 2023Q2 분기의 TF-IDF 키워드 상위 10개:
# 美国 (0.9574), 韩国 (0.8723), 日本 (0.8511), 地区 (0.8511), 战略 (0.8298), 军事 (0.7872), 合作 (0.7872), 安全 (0.7660), 朝鲜 (0.7234), 问题 (0.7234)
#
# ✅ 2023Q3 분기의 TF-IDF 키워드 상위 10개:
# 美国 (0.9060), 日本 (0.8803), 韩国 (0.8376), 举行 (0.8291), 合作 (0.7778), 安全 (0.7692), 地区 (0.7692), 国家 (0.7521), 戴维营 (0.7350), 中国 (0.7009)
#
# ✅ 2023Q4 분기의 TF-IDF 키워드 상위 10개:
# 美国 (0.9250), 韩国 (0.8500), 报道 (0.8250), 日本 (0.7750), 朝鲜 (0.7750), 合作 (0.7250), 联合 (0.7000), 进行 (0.6500), 举行 (0.6500), 地区 (0.6250)
#
# ✅ 2024Q1 분기의 TF-IDF 키워드 상위 10개:
# 美国 (0.9500), 举行 (0.9000), 和平 (0.9000), 局势 (0.8500), 地区 (0.8500), 国家 (0.8500), 国际 (0.8000), 联合 (0.8000), 安全 (0.8000), 问题 (0.7500)
#
# ✅ 2024Q2 분기의 TF-IDF 키워드 상위 10개:
# 美国 (0.9149), 日本 (0.8723), 联合 (0.7872), 合作 (0.7872), 地区 (0.7872), 安全 (0.7660), 举行 (0.7660), 战略 (0.7234), 军事 (0.7021), 问题 (0.6809)
#
# ✅ 2024Q3 분기의 TF-IDF 키워드 상위 10개:
# 美国 (0.9545), 安全 (0.9091), 地区 (0.9091), 国家 (0.8636), 日本 (0.8182), 稳定 (0.8182), 合作 (0.8182), 关系 (0.7727), 中国 (0.7727), 印太 (0.7273)
#
# ✅ 2024Q4 분기의 TF-IDF 키워드 상위 10개:
# 美国 (0.9583), 韩国 (0.8750), 合作 (0.7500), 日本 (0.7083), 报道 (0.6667), 地区 (0.6667), 进行 (0.6250), 联合 (0.6250), 第二 (0.5417), 举行 (0.5417)
#
# ✅ 2025Q1 분기의 TF-IDF 키워드 상위 10개:
# 国家 (1.0000), 联合 (1.0000), 引发 (0.8333), 局势 (0.8333), 美国 (0.8333), 地区 (0.8333), 维护 (0.8333), 同盟 (0.8333), 政策 (0.8333), 朝鲜 (0.6667)
