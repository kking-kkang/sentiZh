# %%
import json
import hanlp
import re
from sklearn.feature_extraction.text import TfidfVectorizer
from collections import Counter
import pandas as pd
from itertools import combinations

# %%
print(hanlp.pretrained.ALL.keys())
# Out:
# dict_keys(['SIGHAN2005_PKU_CONVSEG', 'SIGHAN2005_MSR_CONVSEG', 'CTB6_CONVSEG', 'PKU_NAME_MERGED_SIX_MONTHS_CONVSEG', 'LARGE_ALBERT_BASE', 'SIGHAN2005_PKU_BERT_BASE_ZH', 'COARSE_ELECTRA_SMALL_ZH', 'FINE_ELECTRA_SMALL_ZH', 'CTB9_TOK_ELECTRA_SMALL', 'CTB9_TOK_ELECTRA_BASE', 'CTB9_TOK_ELECTRA_BASE_CRF', 'MSR_TOK_ELECTRA_BASE_CRF', 'KYOTO_EVAHAN_TOK_LZH', 'UD_TOK_MMINILMV2L6', 'UD_TOK_MMINILMV2L12', 'CTB5_BIAFFINE_DEP_ZH', 'CTB7_BIAFFINE_DEP_ZH', 'CTB9_DEP_ELECTRA_SMALL', 'PMT1_DEP_ELECTRA_SMALL', 'CTB9_UDC_ELECTRA_SMALL', 'PTB_BIAFFINE_DEP_EN', 'SEMEVAL16_NEWS_BIAFFINE_ZH', 'SEMEVAL16_TEXT_BIAFFINE_ZH', 'SEMEVAL16_ALL_ELECTRA_SMALL_ZH', 'SEMEVAL15_PAS_BIAFFINE_EN', 'SEMEVAL15_PSD_BIAFFINE_EN', 'SEMEVAL15_DM_BIAFFINE_EN', 'GLOVE_6B_50D', 'GLOVE_6B_100D', 'GLOVE_6B_200D', 'GLOVE_6B_300D', 'GLOVE_840B_300D', 'CTB5_POS_RNN', 'CTB5_POS_RNN_FASTTEXT_ZH', 'CTB9_POS_ALBERT_BASE', 'CTB9_POS_ELECTRA_SMALL_TF', 'CTB9_POS_ELECTRA_SMALL', 'CTB9_POS_RADICAL_ELECTRA_SMALL', 'C863_POS_ELECTRA_SMALL', 'PKU_POS_ELECTRA_SMALL', 'PTB_POS_RNN_FASTTEXT_EN', 'FLAIR_LM_FW_WMT11_EN_TF', 'FLAIR_LM_BW_WMT11_EN_TF', 'FLAIR_LM_WMT11_EN', 'CONVSEG_W2V_NEWS_TENSITE', 'CONVSEG_W2V_NEWS_TENSITE_WORD_PKU', 'CONVSEG_W2V_NEWS_TENSITE_WORD_MSR', 'CONVSEG_W2V_NEWS_TENSITE_CHAR', 'SEMEVAL16_EMBEDDINGS_CN', 'SEMEVAL16_EMBEDDINGS_300_NEWS_CN', 'SEMEVAL16_EMBEDDINGS_300_TEXT_CN', 'CTB5_FASTTEXT_300_CN', 'TENCENT_AILAB_EMBEDDING_SMALL_200', 'TENCENT_AILAB_EMBEDDING_LARGE_200', 'TENCENT_AILAB_EMBEDDING_SMALL_100', 'TENCENT_AILAB_EMBEDDING_LARGE_100', 'MERGE_SGNS_BIGRAM_CHAR_300_ZH', 'RADICAL_CHAR_EMBEDDING_100', 'SUBWORD_ENCODING_CWS_ZH_WIKI_BPE_50', 'SUBWORD_ENCODING_CWS_GIGAWORD_UNI', 'SUBWORD_ENCODING_CWS_GIGAWORD_BI', 'SUBWORD_ENCODING_CWS_CTB_GAZETTEER_50', 'MSRA_NER_BERT_BASE_ZH', 'MSRA_NER_ALBERT_BASE_ZH', 'MSRA_NER_ELECTRA_SMALL_ZH', 'CONLL03_NER_BERT_BASE_CASED_EN', 'CHNSENTICORP_BERT_BASE_ZH', 'SST2_ALBERT_BASE_EN', 'LID_176_FASTTEXT_BASE', 'LID_176_FASTTEXT_SMALL', 'FASTTEXT_DEBUG_EMBEDDING_EN', 'FASTTEXT_CC_300_EN', 'FASTTEXT_WIKI_NYT_AMAZON_FRIENDS_200_EN', 'FASTTEXT_WIKI_300_ZH', 'FASTTEXT_WIKI_300_ZH_CLASSICAL', 'OPEN_TOK_POS_NER_SRL_DEP_SDP_CON_ELECTRA_SMALL_ZH', 'OPEN_TOK_POS_NER_SRL_DEP_SDP_CON_ELECTRA_BASE_ZH', 'CLOSE_TOK_POS_NER_SRL_DEP_SDP_CON_ELECTRA_SMALL_ZH', 'CLOSE_TOK_POS_NER_SRL_UDEP_SDP_CON_ELECTRA_SMALL_ZH', 'CLOSE_TOK_POS_NER_SRL_DEP_SDP_CON_ELECTRA_BASE_ZH', 'CLOSE_TOK_POS_NER_SRL_DEP_SDP_CON_ERNIE_GRAM_ZH', 'KYOTO_EVAHAN_TOK_LEM_POS_UDEP_LZH', 'UD_ONTONOTES_TOK_POS_LEM_FEA_NER_SRL_DEP_SDP_CON_MMINILMV2L6', 'UD_ONTONOTES_TOK_POS_LEM_FEA_NER_SRL_DEP_SDP_CON_MMINILMV2L12', 'UD_ONTONOTES_TOK_POS_LEM_FEA_NER_SRL_DEP_SDP_CON_XLMR_BASE', 'NPCMJ_UD_KYOTO_TOK_POS_CON_BERT_BASE_CHAR_JA', 'EN_TOK_LEM_POS_NER_SRL_UDEP_SDP_CON_MODERNBERT_BASE', 'EN_TOK_LEM_POS_NER_SRL_UDEP_SDP_CON_MODERNBERT_LARGE', 'UD_CTB_EOS_MUL', 'STS_ELECTRA_BASE_ZH', 'CTB9_CON_ELECTRA_SMALL', 'CTB9_CON_FULL_TAG_ELECTRA_SMALL', 'CTB9_CON_FULL_TAG_ERNIE_GRAM', 'AMR3_SEQ2SEQ_BART_LARGE', 'AMR3_GRAPH_PRETRAIN_PARSER', 'MRP2020_AMR_ENG_ZHO_XLM_BASE', 'MRP2020_AMR_ZHO_MENGZI_BASE', 'AMR3_GRAPH_PRETRAIN_GENERATION', 'CPB3_SRL_ELECTRA_SMALL'])

# %%
segmenter = hanlp.load('CTB9_TOK_ELECTRA_BASE_CRF')

# 중국어 불용어 리스트 (예제, 필요시 확장 가능)
chinese_stopwords = set([
    "的", "了", "在", "是", "和", "与", "也", "有", "对", "就", "以", "将", "要",
    "但", "其", "而", "此", "我们", "他们", "你们", "可以", "但是", "这样", "这个",
    "其中", "其中之一", "包括", "根据", "由于", "通过", "此外", "同时",
    "记者", "新闻", "媒体", "采访", "发表", "宣布", "透露", "介绍", "报道称",
    "指出", "强调", "证实", "承认", "认为", "评价", "评论", "提到", "解释", "分析",
    "总结", "预测", "预计", "关注", "反映", "说明", "进一步",
    "今天", "昨天", "明天", "日前", "近日", "本周", "上周", "下周", "目前",
    "现在", "过去", "未来", "今年", "去年", "明年", "此前", "随后", "当地",
    "政府", "机构", "相关", "部门", "官员", "领导人", "代表", "发言人", "部长", "事务", "委员会",
    "一", "二", "三", "这", "不", "可能", "都", "才", "可", "一直", "到", "如果", "将",
    "带来", "十分", "称", "个", "月", "次", "因", "因此", "认为", "如果", "最", "即",
    "当天", "因为", "曾", "号", "第", "等", "相当", "个", "两", "很", "所以", "各种",
    "从而", "仍", "以", "为了", "以及", "据", "并", "过", "几", "号", "立即", "相关",
    "等", "着", "于", "为", "说", "却", "使", "国", "还", "带来", "来说", "而", "为",
    "至", "可以", "很", "会", "除了", "被", "外", "也", "若", "更", "已经", "已", "称",
    "大大", "不仅", "能够", "近日", "并", "再", "一些", "明确", "作为", "向", "于",
    "表示", "以及"
])

# %%
# JSON 파일 로드
file_path = "../data/final_0307.json"
with open(file_path, "r", encoding="utf-8") as f:
    data = json.load(f)

# 결과 저장 리스트
processed_data = []
tokenized_texts = []  # TF 및 TF-IDF 분석용

# 연도 및 분기별 데이터 저장
yearly_data = {}
quarterly_data = {}

# 데이터 처리
for item in data:
    content = item.get("cleaned_content", "")
    date_str = item.get("date")  # 날짜 정보
    quarter = item.get("quarter")  # 분기 정보

    if not date_str or not quarter:
        continue  # 날짜 또는 분기 정보 없는 데이터 제외

    # 날짜에서 연도 추출
    try:
        year = pd.to_datetime(date_str).year
    except:
        continue  # 유효하지 않은 날짜 제외

    # 한자 및 필요 문자만 유지
    clean_text = re.sub(r"[^\u4e00-\u9fff0-9]", "", content)

    # HanLP 토큰화
    tokens = segmenter(clean_text)

    # 불용어 제거
    filtered_tokens = [word for word in tokens if word not in chinese_stopwords]

    # 연도별 데이터 저장
    if year not in yearly_data:
        yearly_data[year] = []
    yearly_data[year].append(filtered_tokens)

    # 분기별 데이터 저장
    if quarter not in quarterly_data:
        quarterly_data[quarter] = []
    quarterly_data[quarter].append(filtered_tokens)

# %%
print("\n📌 분기별 중요 키워드 분석 (TF-IDF)")

for quarter, token_lists in quarterly_data.items():
    tokenized_texts = [" ".join(tokens) for tokens in token_lists]

    # TF-IDF 벡터라이저 적용
    vectorizer = TfidfVectorizer()
    tfidf_matrix = vectorizer.fit_transform(tokenized_texts)

    # 단어 리스트
    feature_names = vectorizer.get_feature_names_out()

    print(f"\n📅 {quarter}분기 중요 키워드 (TF-IDF 상위 10개):")

    # 모든 문서의 평균 TF-IDF 점수 계산
    mean_tfidf_scores = tfidf_matrix.mean(axis=0).A1
    sorted_indices = mean_tfidf_scores.argsort()[::-1]  # 중요도 높은 순으로 정렬
    top_keywords = [feature_names[idx] for idx in sorted_indices[:10]]

    print(top_keywords)
# Out:
# 📌 분기별 중요 키워드 분석 (TF-IDF)
#
# 📅 2006Q3분기 중요 키워드 (TF-IDF 상위 10개):
# ['朝鲜', '导弹', '日本', '发射', '制裁', '美国', '问题', '议案', '防御', '系统']
#
# 📅 2007Q1분기 중요 키워드 (TF-IDF 상위 10개):
# ['会谈', '朝鲜', '美国', '关系', '问题', '正常化', '金桂冠', '希尔', '谈判', '汇业']
#
# 📅 2008Q3분기 중요 키워드 (TF-IDF 상위 10개):
# ['朝鲜', '情报', '韩国', '美国', '可能', '国家', '侦察机', '侦察', '日本', '以及']
#
# 📅 2009Q1분기 중요 키워드 (TF-IDF 상위 10개):
# ['朝鲜', '导弹', '美国', '7日', '韩国', '愿意', '博斯沃思', '对话', '可能', '试射']
#
# 📅 2009Q2분기 중요 키워드 (TF-IDF 상위 10개):
# ['朝鲜', '发射', '声明', '安理会', '中国', '卫星', '美国', '日本', '表示', '葛瑞格森']
#
# 📅 2009Q3분기 중요 키워드 (TF-IDF 상위 10개):
# ['日本', '导弹', '朝鲜', '发射', '行为', '报道', '飞行', '挑衅', '严重', '弹道']
#
# 📅 2010Q1분기 중요 키워드 (TF-IDF 상위 10개):
# ['演习', '联合', '韩国', '参加', '军事', '军演', '美军', '金色', '报道', '眼镜蛇']
#
# 📅 2010Q3분기 중요 키워드 (TF-IDF 상위 10개):
# ['军演', '中国', '美国', '联合', '演习', '日本', '韩国', '朝鲜', '进行', '军事']
#
# 📅 2010Q4분기 중요 키워드 (TF-IDF 상위 10개):
# ['朝鲜', '日本', '美国', '会谈', '中国', '报道', '6日', '韩国', '外长', '半岛']
#
# 📅 2011Q1분기 중요 키워드 (TF-IDF 상위 10개):
# ['朝鲜', '军演', '日本', '韩国', '美国', '军事', '协定', '合作', '战略', '签署']
#
# 📅 2011Q3분기 중요 키워드 (TF-IDF 상위 10개):
# ['问题', '日本', '关系', '首脑', '会谈', '表示', '加强', '发展', '朝鲜', '报道']
#
# 📅 2011Q4분기 중요 키워드 (TF-IDF 상위 10개):
# ['报道', '朝鲜', '问题', '签署', '中国', '对话', '会谈', '日本', '措施', '先决']
#
# 📅 2012Q1분기 중요 키워드 (TF-IDF 상위 10개):
# ['朝鲜', '发射', '卫星', '美国', '南海', '日本', '韩国', '半岛', '拦截', '时报']
#
# 📅 2012Q2분기 중요 키워드 (TF-IDF 상위 10개):
# ['军演', '韩国', '朝鲜', '联合', '美国', '演习', '日本', '军事', '海上', '举行']
#
# 📅 2012Q3분기 중요 키워드 (TF-IDF 상위 10개):
# ['日本', '美国', '韩国', '中国', '问题', '协定', '军事', '情报', '奥巴马', '签署']
#
# 📅 2012Q4분기 중요 키워드 (TF-IDF 상위 10개):
# ['朝鲜', '发射', '卫星', '美国', '日本', '火箭', '韩国', '问题', '表示', '会谈']
#
# 📅 2013Q1분기 중요 키워드 (TF-IDF 상위 10개):
# ['朝鲜', '试验', '日本', '韩国', '美国', '进行', '中国', '导弹', '关系', '问题']
#
# 📅 2013Q2분기 중요 키워드 (TF-IDF 상위 10개):
# ['朝鲜', '导弹', '日本', '美国', '会谈', '韩国', '对话', '问题', '发射', '表示']
#
# 📅 2013Q3분기 중요 키워드 (TF-IDF 상위 10개):
# ['美国', '空军', '日本', '关系', '基地', '设施', '韩国', '演习', '解放', '出来']
#
# 📅 2013Q4분기 중요 키워드 (TF-IDF 상위 10개):
# ['朝鲜', '美国', '演习', '韩国', '海上', '中国', '日本', '会谈', '问题', '航母']
#
# 📅 2014Q1분기 중요 키워드 (TF-IDF 상위 10개):
# ['日本', '美国', '韩国', '关系', '安倍', '会谈', '首脑', '问题', '朴槿惠', '报道']
#
# 📅 2014Q2분기 중요 키워드 (TF-IDF 상위 10개):
# ['美国', '朝鲜', '系统', '韩国', '导弹', '防御', '日本', '磋商', '部署', '中国']
#
# 📅 2014Q3분기 중요 키워드 (TF-IDF 상위 10개):
# ['韩国', '日本', '朝鲜', '演习', '美国', '联合', '军事', '报道', '问题', '进行']
#
# 📅 2014Q4분기 중요 키워드 (TF-IDF 상위 10개):
# ['情报', '韩国', '朝鲜', '日本', '美国', '协议', '签署', '军事', '国防部', '共享']
#
# 📅 2015Q1분기 중요 키워드 (TF-IDF 상위 10개):
# ['韩国', '朝鲜', '美国', '情报', '签署', '日本', '军事', '协议', '金基宗', '协定']
#
# 📅 2015Q2분기 중요 키워드 (TF-IDF 상위 10개):
# ['美国', '日本', '朝鲜', '卡特', '韩国', '安倍', '关系', '导弹', '亚太', '问题']
#
# 📅 2015Q3분기 중요 키워드 (TF-IDF 상위 10개):
# ['朝鲜', '美国', '韩国', '中国', '卫星', '会谈', '报道', '朴槿惠', '发射', '表示']
#
# 📅 2015Q4분기 중요 키워드 (TF-IDF 상위 10개):
# ['韩国', '问题', '慰安妇', '日本', '美国', '朴槿惠', '关系', '解决', '协议', '表示']
#
# 📅 2016Q1분기 중요 키워드 (TF-IDF 상위 10개):
# ['朝鲜', '美国', '韩国', '日本', '问题', '中国', '发射', '系统', '安全', '半岛']
#
# 📅 2016Q2분기 중요 키워드 (TF-IDF 상위 10개):
# ['导弹', '朝鲜', '美国', '军演', '联合', '韩国', '防御', '系统', '日本', '演习']
#
# 📅 2016Q3분기 중요 키워드 (TF-IDF 상위 10개):
# ['萨德', '韩国', '美国', '部署', '系统', '朝鲜', '中国', '反导', '战略', '安全']
#
# 📅 2016Q4분기 중요 키워드 (TF-IDF 상위 10개):
# ['韩国', '协定', '军事', '情报', '签署', '日本', '朝鲜', '合作', '保护', '美国']
#
# 📅 2017Q1분기 중요 키워드 (TF-IDF 상위 10개):
# ['美国', '朝鲜', '韩国', '日本', '特朗普', '中国', '马蒂斯', '关系', '问题', '半岛']
#
# 📅 2017Q2분기 중요 키워드 (TF-IDF 상위 10개):
# ['朝鲜', '韩国', '美国', '导弹', '日本', '演习', '问题', '慰安妇', '军事', '举行']
#
# 📅 2017Q3분기 중요 키워드 (TF-IDF 상위 10개):
# ['朝鲜', '导弹', '美国', '日本', '声明', '安理会', '半岛', '试射', '问题', '发射']
#
# 📅 2017Q4분기 중요 키워드 (TF-IDF 상위 10개):
# ['演习', '韩国', '朝鲜', '导弹', '联合', '美军', '美国', '举行', '同盟', '慰安妇']
#
# 📅 2018Q1분기 중요 키워드 (TF-IDF 상위 10개):
# ['朝鲜', '日本', '半岛', '美国', '韩国', '会谈', '问题', '冬奥会', '举行', '中国']
#
# 📅 2018Q2분기 중요 키워드 (TF-IDF 상위 10개):
# ['会谈', '日本', '安倍', '外长', '报道', '举行', '防长', '内阁', '问题', '朝鲜']
#
# 📅 2018Q3분기 중요 키워드 (TF-IDF 상위 10개):
# ['外长', '会谈', '朝鲜', '蓬佩奥', '关系', '日本', '7月', '三角', '举行', '8日']
#
# 📅 2018Q4분기 중요 키워드 (TF-IDF 상위 10개):
# ['慰安妇', '韩国', '问题', '协议', '日本', '解决', '日方', '民众', '基金会', '方面']
#
# 📅 2019Q1분기 중요 키워드 (TF-IDF 상위 10개):
# ['日本', '韩国', '美国', '会谈', '朝鲜', '雷达', '关系', '特朗普', '问题', '道歉']
#
# 📅 2019Q2분기 중요 키워드 (TF-IDF 상위 10개):
# ['美国', '沙纳汉', '朝鲜', '日本', '地区', '韩国', '拼多多', '战略', '印太', '问题']
#
# 📅 2019Q3분기 중요 키워드 (TF-IDF 상위 10개):
# ['韩国', '日本', '美国', '协定', '军事', '情报', '关系', '表示', '问题', '出口']
#
# 📅 2019Q4분기 중요 키워드 (TF-IDF 상위 10개):
# ['韩国', '协定', '美国', '日本', '军事', '情报', '关系', '保护', '问题', '军情']
#
# 📅 2020Q1분기 중요 키워드 (TF-IDF 상위 10개):
# ['韩国', '美国', '朝鲜', '日本', '会谈', '哈里斯', '表示', '中东', '防卫费', '报道']
#
# 📅 2020Q3분기 중요 키워드 (TF-IDF 상위 10개):
# ['韩国', '日本', '战机', '协定', '美国', '印太', '35', '地区', '航母', '军事']
#
# 📅 2020Q4분기 중요 키워드 (TF-IDF 상위 10개):
# ['拜登', '韩国', '日本', '美国', '通话', '菅义伟', '同盟', '关系', '印太', '地区']
#
# 📅 2021Q1분기 중요 키워드 (TF-IDF 상위 10개):
# ['韩国', '日本', '美国', '关系', '白皮书', '问题', '拜登', '航母', '合作', '矛盾']
#
# 📅 2021Q2분기 중요 키워드 (TF-IDF 상위 10개):
# ['美国', '半导体', '韩国', '朝鲜', '日本', '报道', '举行', '中国', '问题', '会谈']
#
# 📅 2021Q3분기 중요 키워드 (TF-IDF 상위 10개):
# ['导弹', '韩国', '巡航', '朝鲜', '副外长', '美国', '报道', '关系', '远程', '同盟']
#
# 📅 2021Q4분기 중요 키워드 (TF-IDF 상위 10개):
# ['韩国', '日本', '记者会', '问题', '韩方', '会谈', '日方', '报道', '关系', '舍曼']
#
# 📅 2022Q1분기 중요 키워드 (TF-IDF 상위 10개):
# ['美国', '地区', '北约', '印太', '尹锡悦', '韩国', '报告', '朝鲜', '安全', '战略']
#
# 📅 2022Q2분기 중요 키워드 (TF-IDF 상위 10개):
# ['美国', '韩国', '拜登', '日本', '会谈', '北约', '安全', '印太', '中国', '地区']
#
# 📅 2022Q3분기 중요 키워드 (TF-IDF 상위 10개):
# ['演习', '韩国', '美国', '北约', '日本', '关系', '军演', '导弹', '联合', '朝鲜']
#
# 📅 2022Q4분기 중요 키워드 (TF-IDF 상위 10개):
# ['韩国', '日本', '美国', '朝鲜', '战略', '外交', '中国', '威慑', '会谈', '举行']
#
# 📅 2023Q1분기 중요 키워드 (TF-IDF 상위 10개):
# ['韩国', '美国', '日本', '同盟', '中国', '合作', '地区', '安全', '关系', '亚太']
#
# 📅 2023Q2분기 중요 키워드 (TF-IDF 상위 10개):
# ['韩国', '美国', '日本', '尹锡悦', '问题', '关系', '地区', '战略', '朝鲜', '中国']
#
# 📅 2023Q3분기 중요 키워드 (TF-IDF 상위 10개):
# ['美国', '韩国', '日本', '中国', '地区', '合作', '报道', '朝鲜', '安全', '国家']
#
# 📅 2023Q4분기 중요 키워드 (TF-IDF 상위 10개):
# ['朝鲜', '韩国', '美国', '报道', '演习', '半岛', '合作', '战略', '日本', '举行']
#
# 📅 2024Q1분기 중요 키워드 (TF-IDF 상위 10개):
# ['朝鲜', '中国', '美国', '韩国', '日本', '演习', '安全', '地区', '军事', '合作']
#
# 📅 2024Q2분기 중요 키워드 (TF-IDF 상위 10개):
# ['美国', '日本', '合作', '中国', '韩国', '地区', '联合', '安全', '举行', '演习']
#
# 📅 2024Q3분기 중요 키워드 (TF-IDF 상위 10개):
# ['美国', '中国', '日本', '地区', '合作', '美军', '司令部', '军事', '安全', '亚太']
#
# 📅 2024Q4분기 중요 키워드 (TF-IDF 상위 10개):
# ['韩国', '演习', '朝鲜', '日本', '美国', '联合', '中国', '关系', '作战', '尹锡悦']
#
# 📅 2025Q1분기 중요 키워드 (TF-IDF 상위 10개):
# ['韩国', '谈话', '美国', '尹锡悦', '军事', '行为', '地区', '外交', '特朗普', '安全']

# %%
print("\n📌 연도별 중요 키워드 분석 (TF-IDF)")

# 연도별 키워드 및 N-그램 저장 딕셔너리
yearly_bigrams = {}
yearly_trigrams = {}

for year, token_lists in yearly_data.items():
    tokenized_texts = [" ".join(tokens) for tokens in token_lists]

    # TF-IDF 벡터라이저 적용
    vectorizer = TfidfVectorizer()
    tfidf_matrix = vectorizer.fit_transform(tokenized_texts)

    # 단어 리스트
    feature_names = vectorizer.get_feature_names_out()

    print(f"\n📅 {year}년 중요 키워드 (TF-IDF 상위 10개):")

    # 모든 문서의 평균 TF-IDF 점수 계산
    mean_tfidf_scores = tfidf_matrix.mean(axis=0).A1
    sorted_indices = mean_tfidf_scores.argsort()[::-1]  # 중요도 높은 순으로 정렬
    top_keywords = [feature_names[idx] for idx in sorted_indices[:10]]

    print(top_keywords)

    bigram_counter = Counter()
    trigram_counter = Counter()

    # 연도별 전체 기사에서 키워드 추출
    for tokens in token_lists:
        # 2-그램, 3-그램 조합 생성
        if len(tokens) >= 2:
            bigram_counter.update(combinations(tokens, 2))
        if len(tokens) >= 3:
            trigram_counter.update(combinations(tokens, 3))

    # 연도별 N-그램 저장
    yearly_bigrams[year] = bigram_counter.most_common(10)  # 상위 10개 2-그램
    yearly_trigrams[year] = trigram_counter.most_common(10)  # 상위 10개 3-그램
# Out:
# 📌 연도별 중요 키워드 분석 (TF-IDF)
#
# 📅 2006년 중요 키워드 (TF-IDF 상위 10개):
# ['朝鲜', '导弹', '日本', '发射', '制裁', '计划', '防御', '问题', '推动', '议案']
#
# 📅 2007년 중요 키워드 (TF-IDF 상위 10개):
# ['会谈', '朝鲜', '美国', '关系', '问题', '正常化', '金桂冠', '希尔', '纽约', '银行']
#
# 📅 2008년 중요 키워드 (TF-IDF 상위 10개):
# ['朝鲜', '情报', '韩国', '美国', '侦察机', '日本', '国家', '侦察', '金正日', '这些']
#
# 📅 2009년 중요 키워드 (TF-IDF 상위 10개):
# ['朝鲜', '导弹', '发射', '美国', '声明', '日本', '中国', '韩国', '安理会', '卫星']
#
# 📅 2010년 중요 키워드 (TF-IDF 상위 10개):
# ['朝鲜', '日本', '中国', '美国', '军演', '韩国', '会谈', '演习', '联合', '报道']
#
# 📅 2011년 중요 키워드 (TF-IDF 상위 10개):
# ['朝鲜', '日本', '军演', '军事', '韩国', '美国', '签署', '问题', '协定', '合作']
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[77], line 35
#      33         bigram_counter.update(combinations(tokens, 2))
#      34     if len(tokens) >= 3:
# ---> 35         trigram_counter.update(combinations(tokens, 3))
#      37 # 연도별 N-그램 저장
#      38 yearly_bigrams[year] = bigram_counter.most_common(10)  # 상위 10개 2-그램
#
# File ~\AppData\Local\Programs\Python\Python310\lib\collections\__init__.py:670, in Counter.update(self, iterable, **kwds)
#     668             super().update(iterable)
#     669     else:
# --> 670         _count_elements(self, iterable)
#     671 if kwds:
#     672     self.update(kwds)
#
# MemoryError:

# %%
# 📌 3. 연도별 N-그램 결과 출력
print("\n✅ 연도별 상위 10개 2-그램:")
for year, bigrams in yearly_bigrams.items():
    print(f"\n📅 {year}년:")
    print(bigrams)

print("\n✅ 연도별 상위 10개 3-그램:")
for year, trigrams in yearly_trigrams.items():
    print(f"\n📅 {year}년:")
    print(trigrams)
# Out:
# ✅ 연도별 상위 10개 2-그램:
#
# 📅 2006년:
# [(('朝鲜', '导弹'), 1), (('朝鲜', '日本'), 1), (('朝鲜', '发射'), 1), (('朝鲜', '制裁'), 1), (('朝鲜', '计划'), 1), (('朝鲜', '防御'), 1), (('朝鲜', '问题'), 1), (('朝鲜', '推动'), 1), (('朝鲜', '议案'), 1), (('导弹', '日本'), 1)]
#
# 📅 2007년:
# [(('会谈', '朝鲜'), 1), (('会谈', '美国'), 1), (('会谈', '关系'), 1), (('会谈', '问题'), 1), (('会谈', '正常化'), 1), (('会谈', '金桂冠'), 1), (('会谈', '希尔'), 1), (('会谈', '纽约'), 1), (('会谈', '银行'), 1), (('朝鲜', '美国'), 1)]
#
# 📅 2008년:
# [(('朝鲜', '情报'), 1), (('朝鲜', '韩国'), 1), (('朝鲜', '美国'), 1), (('朝鲜', '侦察机'), 1), (('朝鲜', '日本'), 1), (('朝鲜', '国家'), 1), (('朝鲜', '侦察'), 1), (('朝鲜', '金正日'), 1), (('朝鲜', '这些'), 1), (('情报', '韩国'), 1)]
#
# 📅 2009년:
# [(('朝鲜', '导弹'), 1), (('朝鲜', '发射'), 1), (('朝鲜', '美国'), 1), (('朝鲜', '声明'), 1), (('朝鲜', '日本'), 1), (('朝鲜', '中国'), 1), (('朝鲜', '韩国'), 1), (('朝鲜', '安理会'), 1), (('朝鲜', '卫星'), 1), (('导弹', '发射'), 1)]
#
# 📅 2010년:
# [(('朝鲜', '日本'), 1), (('朝鲜', '中国'), 1), (('朝鲜', '美国'), 1), (('朝鲜', '军演'), 1), (('朝鲜', '韩国'), 1), (('朝鲜', '会谈'), 1), (('朝鲜', '演习'), 1), (('朝鲜', '联合'), 1), (('朝鲜', '报道'), 1), (('日本', '中国'), 1)]
#
# 📅 2011년:
# [(('朝鲜', '日本'), 1), (('朝鲜', '军演'), 1), (('朝鲜', '军事'), 1), (('朝鲜', '韩国'), 1), (('朝鲜', '美国'), 1), (('朝鲜', '签署'), 1), (('朝鲜', '问题'), 1), (('朝鲜', '协定'), 1), (('朝鲜', '合作'), 1), (('日本', '军演'), 1)]
#
# 📅 2012년:
# [(('朝鲜', '美国'), 1), (('朝鲜', '日本'), 1), (('朝鲜', '发射'), 1), (('朝鲜', '韩国'), 1), (('朝鲜', '军演'), 1), (('朝鲜', '卫星'), 1), (('朝鲜', '中国'), 1), (('朝鲜', '演习'), 1), (('朝鲜', '联合'), 1), (('美国', '日本'), 1)]
#
# 📅 2013년:
# [(('朝鲜', '导弹'), 1), (('朝鲜', '美国'), 1), (('朝鲜', '日本'), 1), (('朝鲜', '韩国'), 1), (('朝鲜', '会谈'), 1), (('朝鲜', '中国'), 1), (('朝鲜', '问题'), 1), (('朝鲜', '试验'), 1), (('朝鲜', '对话'), 1), (('导弹', '美国'), 1)]
#
# 📅 2014년:
# [(('日本', '韩国'), 1), (('日本', '美国'), 1), (('日本', '朝鲜'), 1), (('日本', '情报'), 1), (('日本', '会谈'), 1), (('日本', '问题'), 1), (('日本', '关系'), 1), (('日本', '导弹'), 1), (('日本', '安倍'), 1), (('韩国', '美国'), 1)]
#
# 📅 2015년:
# [(('韩国', '美国'), 1), (('韩国', '朝鲜'), 1), (('韩国', '日本'), 1), (('韩国', '问题'), 1), (('韩国', '关系'), 1), (('韩国', '慰安妇'), 1), (('韩国', '会谈'), 1), (('韩国', '朴槿惠'), 1), (('韩国', '卡特'), 1), (('美国', '朝鲜'), 1)]
#
# 📅 2016년:
# [(('韩国', '朝鲜'), 1), (('韩国', '美国'), 1), (('韩国', '萨德'), 1), (('韩国', '系统'), 1), (('韩国', '部署'), 1), (('韩国', '日本'), 1), (('韩国', '中国'), 1), (('韩国', '军事'), 1), (('韩国', '导弹'), 1), (('朝鲜', '美国'), 1)]
#
# 📅 2017년:
# [(('朝鲜', '美国'), 1), (('朝鲜', '韩国'), 1), (('朝鲜', '导弹'), 1), (('朝鲜', '日本'), 1), (('朝鲜', '问题'), 1), (('朝鲜', '特朗普'), 1), (('朝鲜', '中国'), 1), (('朝鲜', '半岛'), 1), (('朝鲜', '关系'), 1), (('美国', '韩国'), 1)]
#
# 📅 2018년:
# [(('日本', '会谈'), 1), (('日本', '朝鲜'), 1), (('日本', '韩国'), 1), (('日本', '美国'), 1), (('日本', '半岛'), 1), (('日本', '问题'), 1), (('日本', '举行'), 1), (('日本', '外长'), 1), (('日本', '安倍'), 1), (('会谈', '朝鲜'), 1)]
#
# 📅 2019년:
# [(('韩国', '日本'), 1), (('韩国', '美国'), 1), (('韩国', '协定'), 1), (('韩国', '军事'), 1), (('韩国', '关系'), 1), (('韩国', '情报'), 1), (('韩国', '问题'), 1), (('韩国', '韩方'), 1), (('韩国', '贸易'), 1), (('日本', '美国'), 1)]
#
# 📅 2020년:
# [(('韩国', '美国'), 1), (('韩国', '日本'), 1), (('韩国', '朝鲜'), 1), (('韩国', '协定'), 1), (('韩国', '地区'), 1), (('韩国', '会谈'), 1), (('韩国', '印太'), 1), (('韩国', '哈里斯'), 1), (('韩国', '战机'), 1), (('美国', '日本'), 1)]
#
# 📅 2021년:
# [(('韩国', '美国'), 1), (('韩国', '日本'), 1), (('韩国', '朝鲜'), 1), (('韩国', '关系'), 1), (('韩国', '问题'), 1), (('韩国', '导弹'), 1), (('韩国', '半导体'), 1), (('韩国', '报道'), 1), (('韩国', '会谈'), 1), (('美国', '日本'), 1)]
#
# 📅 2022년:
# [(('韩国', '美国'), 1), (('韩国', '日本'), 1), (('韩国', '北约'), 1), (('韩国', '朝鲜'), 1), (('韩国', '演习'), 1), (('韩国', '关系'), 1), (('韩国', '地区'), 1), (('韩国', '中国'), 1), (('韩国', '合作'), 1), (('美国', '日本'), 1)]
#
# 📅 2023년:
# [(('美国', '韩国'), 1), (('美国', '日本'), 1), (('美国', '朝鲜'), 1), (('美国', '中国'), 1), (('美国', '地区'), 1), (('美国', '合作'), 1), (('美国', '报道'), 1), (('美国', '安全'), 1), (('美国', '关系'), 1), (('韩国', '日本'), 1)]
#
# 📅 2024년:
# [(('美国', '日本'), 1), (('美国', '中国'), 1), (('美国', '韩国'), 1), (('美国', '合作'), 1), (('美国', '演习'), 1), (('美国', '地区'), 1), (('美国', '朝鲜'), 1), (('美国', '安全'), 1), (('美国', '联合'), 1), (('日本', '中国'), 1)]
#
# 📅 2025년:
# [(('韩国', '谈话'), 1), (('韩国', '美国'), 1), (('韩国', '尹锡悦'), 1), (('韩国', '军事'), 1), (('韩国', '行为'), 1), (('韩国', '地区'), 1), (('韩国', '外交'), 1), (('韩国', '特朗普'), 1), (('韩国', '安全'), 1), (('谈话', '美国'), 1)]
#
# ✅ 연도별 상위 10개 3-그램:
#
# 📅 2006년:
# [(('朝鲜', '导弹', '日本'), 1), (('朝鲜', '导弹', '发射'), 1), (('朝鲜', '导弹', '制裁'), 1), (('朝鲜', '导弹', '计划'), 1), (('朝鲜', '导弹', '防御'), 1), (('朝鲜', '导弹', '问题'), 1), (('朝鲜', '导弹', '推动'), 1), (('朝鲜', '导弹', '议案'), 1), (('朝鲜', '日本', '发射'), 1), (('朝鲜', '日本', '制裁'), 1)]
#
# 📅 2007년:
# [(('会谈', '朝鲜', '美国'), 1), (('会谈', '朝鲜', '关系'), 1), (('会谈', '朝鲜', '问题'), 1), (('会谈', '朝鲜', '正常化'), 1), (('会谈', '朝鲜', '金桂冠'), 1), (('会谈', '朝鲜', '希尔'), 1), (('会谈', '朝鲜', '纽约'), 1), (('会谈', '朝鲜', '银行'), 1), (('会谈', '美国', '关系'), 1), (('会谈', '美国', '问题'), 1)]
#
# 📅 2008년:
# [(('朝鲜', '情报', '韩国'), 1), (('朝鲜', '情报', '美国'), 1), (('朝鲜', '情报', '侦察机'), 1), (('朝鲜', '情报', '日本'), 1), (('朝鲜', '情报', '国家'), 1), (('朝鲜', '情报', '侦察'), 1), (('朝鲜', '情报', '金正日'), 1), (('朝鲜', '情报', '这些'), 1), (('朝鲜', '韩国', '美国'), 1), (('朝鲜', '韩国', '侦察机'), 1)]
#
# 📅 2009년:
# [(('朝鲜', '导弹', '发射'), 1), (('朝鲜', '导弹', '美国'), 1), (('朝鲜', '导弹', '声明'), 1), (('朝鲜', '导弹', '日本'), 1), (('朝鲜', '导弹', '中国'), 1), (('朝鲜', '导弹', '韩国'), 1), (('朝鲜', '导弹', '安理会'), 1), (('朝鲜', '导弹', '卫星'), 1), (('朝鲜', '发射', '美国'), 1), (('朝鲜', '发射', '声明'), 1)]
#
# 📅 2010년:
# [(('朝鲜', '日本', '中国'), 1), (('朝鲜', '日本', '美国'), 1), (('朝鲜', '日本', '军演'), 1), (('朝鲜', '日本', '韩国'), 1), (('朝鲜', '日本', '会谈'), 1), (('朝鲜', '日本', '演习'), 1), (('朝鲜', '日本', '联合'), 1), (('朝鲜', '日本', '报道'), 1), (('朝鲜', '中国', '美国'), 1), (('朝鲜', '中国', '军演'), 1)]
#
# 📅 2011년:
# [(('朝鲜', '日本', '军演'), 1), (('朝鲜', '日本', '军事'), 1), (('朝鲜', '日本', '韩国'), 1), (('朝鲜', '日本', '美国'), 1), (('朝鲜', '日本', '签署'), 1), (('朝鲜', '日本', '问题'), 1), (('朝鲜', '日本', '协定'), 1), (('朝鲜', '日本', '合作'), 1), (('朝鲜', '军演', '军事'), 1), (('朝鲜', '军演', '韩国'), 1)]
#
# 📅 2012년:
# [(('朝鲜', '美国', '日本'), 1), (('朝鲜', '美国', '发射'), 1), (('朝鲜', '美国', '韩国'), 1), (('朝鲜', '美国', '军演'), 1), (('朝鲜', '美国', '卫星'), 1), (('朝鲜', '美国', '中国'), 1), (('朝鲜', '美国', '演习'), 1), (('朝鲜', '美国', '联合'), 1), (('朝鲜', '日本', '发射'), 1), (('朝鲜', '日本', '韩国'), 1)]
#
# 📅 2013년:
# [(('朝鲜', '导弹', '美国'), 1), (('朝鲜', '导弹', '日本'), 1), (('朝鲜', '导弹', '韩国'), 1), (('朝鲜', '导弹', '会谈'), 1), (('朝鲜', '导弹', '中国'), 1), (('朝鲜', '导弹', '问题'), 1), (('朝鲜', '导弹', '试验'), 1), (('朝鲜', '导弹', '对话'), 1), (('朝鲜', '美国', '日本'), 1), (('朝鲜', '美国', '韩国'), 1)]
#
# 📅 2014년:
# [(('日本', '韩国', '美国'), 1), (('日本', '韩国', '朝鲜'), 1), (('日本', '韩国', '情报'), 1), (('日本', '韩国', '会谈'), 1), (('日本', '韩国', '问题'), 1), (('日本', '韩国', '关系'), 1), (('日本', '韩国', '导弹'), 1), (('日本', '韩国', '安倍'), 1), (('日本', '美国', '朝鲜'), 1), (('日本', '美国', '情报'), 1)]
#
# 📅 2015년:
# [(('韩国', '美国', '朝鲜'), 1), (('韩国', '美国', '日本'), 1), (('韩国', '美国', '问题'), 1), (('韩国', '美国', '关系'), 1), (('韩国', '美国', '慰安妇'), 1), (('韩国', '美国', '会谈'), 1), (('韩国', '美国', '朴槿惠'), 1), (('韩国', '美国', '卡特'), 1), (('韩国', '朝鲜', '日本'), 1), (('韩国', '朝鲜', '问题'), 1)]
#
# 📅 2016년:
# [(('韩国', '朝鲜', '美国'), 1), (('韩国', '朝鲜', '萨德'), 1), (('韩国', '朝鲜', '系统'), 1), (('韩国', '朝鲜', '部署'), 1), (('韩国', '朝鲜', '日本'), 1), (('韩国', '朝鲜', '中国'), 1), (('韩国', '朝鲜', '军事'), 1), (('韩国', '朝鲜', '导弹'), 1), (('韩国', '美国', '萨德'), 1), (('韩国', '美国', '系统'), 1)]
#
# 📅 2017년:
# [(('朝鲜', '美国', '韩国'), 1), (('朝鲜', '美国', '导弹'), 1), (('朝鲜', '美国', '日本'), 1), (('朝鲜', '美国', '问题'), 1), (('朝鲜', '美国', '特朗普'), 1), (('朝鲜', '美国', '中国'), 1), (('朝鲜', '美国', '半岛'), 1), (('朝鲜', '美国', '关系'), 1), (('朝鲜', '韩国', '导弹'), 1), (('朝鲜', '韩国', '日本'), 1)]
#
# 📅 2018년:
# [(('日本', '会谈', '朝鲜'), 1), (('日本', '会谈', '韩国'), 1), (('日本', '会谈', '美国'), 1), (('日本', '会谈', '半岛'), 1), (('日本', '会谈', '问题'), 1), (('日本', '会谈', '举行'), 1), (('日本', '会谈', '外长'), 1), (('日本', '会谈', '安倍'), 1), (('日本', '朝鲜', '韩国'), 1), (('日本', '朝鲜', '美国'), 1)]
#
# 📅 2019년:
# [(('韩国', '日本', '美国'), 1), (('韩国', '日本', '协定'), 1), (('韩国', '日本', '军事'), 1), (('韩国', '日本', '关系'), 1), (('韩国', '日本', '情报'), 1), (('韩国', '日本', '问题'), 1), (('韩国', '日本', '韩方'), 1), (('韩国', '日本', '贸易'), 1), (('韩国', '美国', '协定'), 1), (('韩国', '美国', '军事'), 1)]
#
# 📅 2020년:
# [(('韩国', '美国', '日本'), 1), (('韩国', '美国', '朝鲜'), 1), (('韩国', '美国', '协定'), 1), (('韩国', '美国', '地区'), 1), (('韩国', '美国', '会谈'), 1), (('韩国', '美国', '印太'), 1), (('韩国', '美国', '哈里斯'), 1), (('韩国', '美国', '战机'), 1), (('韩国', '日本', '朝鲜'), 1), (('韩国', '日本', '协定'), 1)]
#
# 📅 2021년:
# [(('韩国', '美国', '日本'), 1), (('韩国', '美国', '朝鲜'), 1), (('韩国', '美国', '关系'), 1), (('韩国', '美国', '问题'), 1), (('韩国', '美国', '导弹'), 1), (('韩国', '美国', '半导体'), 1), (('韩国', '美国', '报道'), 1), (('韩国', '美国', '会谈'), 1), (('韩国', '日本', '朝鲜'), 1), (('韩国', '日本', '关系'), 1)]
#
# 📅 2022년:
# [(('韩国', '美国', '日本'), 1), (('韩国', '美国', '北约'), 1), (('韩国', '美国', '朝鲜'), 1), (('韩国', '美国', '演习'), 1), (('韩国', '美国', '关系'), 1), (('韩国', '美国', '地区'), 1), (('韩国', '美国', '中国'), 1), (('韩国', '美国', '合作'), 1), (('韩国', '日本', '北约'), 1), (('韩国', '日本', '朝鲜'), 1)]
#
# 📅 2023년:
# [(('美国', '韩国', '日本'), 1), (('美国', '韩国', '朝鲜'), 1), (('美国', '韩国', '中国'), 1), (('美国', '韩国', '地区'), 1), (('美国', '韩国', '合作'), 1), (('美国', '韩国', '报道'), 1), (('美国', '韩国', '安全'), 1), (('美国', '韩国', '关系'), 1), (('美国', '日本', '朝鲜'), 1), (('美国', '日本', '中国'), 1)]
#
# 📅 2024년:
# [(('美国', '日本', '中国'), 1), (('美国', '日本', '韩国'), 1), (('美国', '日本', '合作'), 1), (('美国', '日本', '演习'), 1), (('美国', '日本', '地区'), 1), (('美国', '日本', '朝鲜'), 1), (('美国', '日本', '安全'), 1), (('美国', '日本', '联合'), 1), (('美国', '中国', '韩国'), 1), (('美国', '中国', '合作'), 1)]
#
# 📅 2025년:
# [(('韩国', '谈话', '美国'), 1), (('韩国', '谈话', '尹锡悦'), 1), (('韩国', '谈话', '军事'), 1), (('韩国', '谈话', '行为'), 1), (('韩国', '谈话', '地区'), 1), (('韩国', '谈话', '外交'), 1), (('韩国', '谈话', '特朗普'), 1), (('韩国', '谈话', '安全'), 1), (('韩国', '美国', '尹锡悦'), 1), (('韩国', '美国', '军事'), 1)]

# %%
# 📌 4. 데이터프레임 변환 (시각화 및 저장을 위해)
bigram_df = pd.DataFrame(
    [(year, " → ".join(pair), count) for year, bigrams in yearly_bigrams.items() for pair, count in bigrams],
    columns=["year", "bigram", "count"]
)

trigram_df = pd.DataFrame(
    [(year, " → ".join(pair), count) for year, trigrams in yearly_trigrams.items() for pair, count in trigrams],
    columns=["year", "trigram", "count"]
)

# %%
# 📌 5. CSV 파일로 저장
bigram_csv_path = "../data/yearly_bigram.csv"
trigram_csv_path = "../data/yearly_trigram.csv"

bigram_df.to_csv(bigram_csv_path, index=False, encoding="utf-8-sig")
trigram_df.to_csv(trigram_csv_path, index=False, encoding="utf-8-sig")

print(f"\n✅ 연도별 2-그램 CSV 저장 완료: {bigram_csv_path}")
print(f"✅ 연도별 3-그램 CSV 저장 완료: {trigram_csv_path}")

# 📌 6. JSON 파일로 저장
output_json_path = "../data/yearly_keyword_ngrams.json"
ngrams_data = {
    "bigrams": yearly_bigrams,
    "trigrams": yearly_trigrams,
}
with open(output_json_path, "w", encoding="utf-8") as f:
    json.dump(ngrams_data, f, indent=4, ensure_ascii=False)

print(f"\n✅ 연도별 키워드 기반 N-그램 분석 결과 저장 완료: {output_json_path}")
# Out:
# ✅ 연도별 2-그램 CSV 저장 완료: ../data/yearly_bigram.csv
# ✅ 연도별 3-그램 CSV 저장 완료: ../data/yearly_trigram.csv
#
# ✅ 연도별 키워드 기반 N-그램 분석 결과 저장 완료: ../data/yearly_keyword_ngrams.json

# %%
print("\n📌 분기별 단어 빈도 분석 (TF)")

for quarter, token_lists in quarterly_data.items():
    all_words = [word for tokens in token_lists for word in tokens]
    word_freq = Counter(all_words)

    print(f"\n📅 {quarter}분기 가장 많이 등장한 키워드 (TF 상위 10개):")
    for word, freq in word_freq.most_common(10):
        print(f"{word}: {freq}회")
# Out:
# 📌 분기별 단어 빈도 분석 (TF)
#
# 📅 2006Q3분기 가장 많이 등장한 키워드 (TF 상위 10개):
# 朝鲜: 10회
# 导弹: 7회
# 日本: 6회
# 日: 5회
# 发射: 4회
# 美: 4회
# 制裁: 3회
# 次: 3회
# 国际: 2회
# 安理会: 2회
#
# 📅 2007Q1분기 가장 많이 등장한 키워드 (TF 상위 10개):
# 会谈: 16회
# 朝鲜: 13회
# 朝: 13회
# 美国: 12회
# 美: 12회
# 关系: 10회
# 问题: 7회
# 两: 6회
# 国: 6회
# 正常化: 6회
#
# 📅 2008Q3분기 가장 많이 등장한 키워드 (TF 상위 10개):
# 朝鲜: 53회
# 情报: 33회
# 三: 17회
# 国: 17회
# 韩国: 14회
# 核: 13회
# 美国: 11회
# 美: 11회
# 国家: 8회
# 侦察机: 8회
#
# 📅 2009Q1분기 가장 많이 등장한 키워드 (TF 상위 10개):
# 朝鲜: 61회
# 导弹: 61회
# 韩国: 17회
# 可能: 16회
# 美: 15회
# 试射: 15회
# 公里: 13회
# 美国: 12회
# 韩: 11회
# 日: 11회
#
# 📅 2009Q2분기 가장 많이 등장한 키워드 (TF 상위 10개):
# 朝鲜: 66회
# 发射: 28회
# 说: 24회
# 美国: 21회
# 声明: 19회
# 日: 18회
# 韩国: 17회
# 日本: 17회
# 安理会: 16회
# 并: 15회
#
# 📅 2009Q3분기 가장 많이 등장한 키워드 (TF 상위 10개):
# 导弹: 6회
# 日本: 6회
# 朝鲜: 5회
# 称: 4회
# 发射: 4회
# 报道: 3회
# 据: 3회
# 行为: 3회
# 枚: 2회
# 安全: 2회
#
# 📅 2010Q1분기 가장 많이 등장한 키워드 (TF 상위 10개):
# 演习: 7회
# 联合: 6회
# 国: 6회
# 韩国: 5회
# 参加: 5회
# 军事: 5회
# 军演: 4회
# 报道: 3회
# 美军: 3회
# 表示: 3회
#
# 📅 2010Q3분기 가장 많이 등장한 키워드 (TF 상위 10개):
# 美: 45회
# 韩: 44회
# 军演: 40회
# 美国: 28회
# 联合: 27회
# 中国: 26회
# 次: 25회
# 演习: 23회
# 一: 22회
# 日本: 19회
#
# 📅 2010Q4분기 가장 많이 등장한 키워드 (TF 상위 10개):
# 朝鲜: 52회
# 韩: 49회
# 美: 47회
# 日本: 46회
# 美国: 44회
# 日: 36회
# 三: 34회
# 国: 33회
# 中国: 32회
# 会谈: 27회
#
# 📅 2011Q1분기 가장 많이 등장한 키워드 (TF 상위 10개):
# 美国: 87회
# 韩: 79회
# 日: 67회
# 朝鲜: 61회
# 韩国: 51회
# 国: 48회
# 军事: 48회
# 一: 48회
# 美: 46회
# 国家: 46회
#
# 📅 2011Q3분기 가장 많이 등장한 키워드 (TF 상위 10개):
# 国: 8회
# 日: 8회
# 韩: 8회
# 问题: 7회
# 日本: 5회
# 两: 5회
# 会谈: 4회
# 首脑: 4회
# 关系: 4회
# 报道: 3회
#
# 📅 2011Q4분기 가장 많이 등장한 키워드 (TF 상위 10개):
# 日: 11회
# 韩: 10회
# 国: 10회
# 报道: 7회
# 三: 6회
# 问题: 6회
# 朝: 6회
# 日本: 5회
# 美: 5회
# 朝鲜: 5회
#
# 📅 2012Q1분기 가장 많이 등장한 키워드 (TF 상위 10개):
# 朝鲜:
q4분기 가장 많이 등장한 키워드 (TF 상위 10개):
# 美国: 261회
# 美: 242회
# 韩国: 226회
# 朝鲜: 202회
# 韩: 192회
# 日: 145회
# 合作: 142회
# 称: 131회
# 地区: 129회
# 报道: 127회
#
# 📅 2024Q1분기 가장 많이 등장한 키워드 (TF 상위 10개):
# 美: 193회
# 韩: 163회
# 中国: 159회
# 美国: 143회
# 日: 130회
# 朝鲜: 118회
# 安全: 116회
# 地区: 109회
# 国家: 96회
# 不: 95회
#
# 📅 2024Q2분기 가장 많이 등장한 키워드 (TF 상위 10개):
# 日: 487회
# 美: 485회
# 美国: 445회
# 日本: 349회
# 韩: 283회
# 国: 280회
# 中国: 274회
# 合作: 271회
# 中: 270회
# 三: 248회
#
# 📅 2024Q3분기 가장 많이 등장한 키워드 (TF 상위 10개):
# 美国: 263회
# 日: 244회
# 美: 215회
# 日本: 144회
# 中国: 144회
# 地区: 129회
# 韩: 114회
# 美军: 108회
# 一: 106회
# 合作: 106회
#
# 📅 2024Q4분기 가장 많이 등장한 키워드 (TF 상위 10개):
# 韩国: 193회
# 美: 150회
# 韩: 150회
# 日: 129회
# 美国: 120회
# 中国: 108회
# 日本: 94회
# 演习: 90회
# 等: 89회
# 游戏: 85회
#
# 📅 2025Q1분기 가장 많이 등장한 키워드 (TF 상위 10개):
# 美: 74회
# 韩: 53회
# 日: 52회
# 韩国: 48회
# 美国: 45회
# 尹锡悦: 38회
# 特朗普: 30회
# 外交: 26회
# 一: 23회
# 不: 23회

# %%
print("\n📌 연도별 단어 빈도 분석 (TF)")

for year, token_lists in yearly_data.items():
    all_words = [word for tokens in token_lists for word in tokens]
    word_freq = Counter(all_words)

    print(f"\n📅 {year}년 가장 많이 등장한 키워드 (TF 상위 10개):")
    for word, freq in word_freq.most_common(10):
        print(f"{word}: {freq}회")
# Out:
# 📌 연도별 단어 빈도 분석 (TF)
#
# 📅 2006년 가장 많이 등장한 키워드 (TF 상위 10개):
# 朝鲜: 10회
# 导弹: 7회
# 日本: 6회
# 日: 5회
# 发射: 4회
# 美: 4회
# 制裁: 3회
# 次: 3회
# 国际: 2회
# 安理会: 2회
#
# 📅 2007년 가장 많이 등장한 키워드 (TF 상위 10개):
# 会谈: 16회
# 朝鲜: 13회
# 朝: 13회
# 美国: 12회
# 美: 12회
# 关系: 10회
# 问题: 7회
# 两: 6회
# 国: 6회
# 正常化: 6회
#
# 📅 2008년 가장 많이 등장한 키워드 (TF 상위 10개):
# 朝鲜: 53회
# 情报: 33회
# 三: 17회
# 国: 17회
# 韩国: 14회
# 核: 13회
# 美国: 11회
# 美: 11회
# 国家: 8회
# 侦察机: 8회
#
# 📅 2009년 가장 많이 등장한 키워드 (TF 상위 10개):
# 朝鲜: 132회
# 导弹: 68회
# 发射: 41회
# 韩国: 35회
# 美国: 33회
# 日本: 30회
# 日: 29회
# 说: 28회
# 美: 26회
# 可能: 22회
#
# 📅 2010년 가장 많이 등장한 키워드 (TF 상위 10개):
# 韩: 94회
# 美: 93회
# 美国: 73회
# 朝鲜: 68회
# 日本: 66회
# 军演: 65회
# 中国: 58회
# 国: 55회
# 日: 47회
# 一: 47회
#
# 📅 2011년 가장 많이 등장한 키워드 (TF 상위 10개):
# 韩: 97회
# 美国: 89회
# 日: 86회
# 朝鲜: 69회
# 国: 66회
# 韩国: 56회
# 美: 54회
# 日本: 51회
# 一: 49회
# 军事: 48회
#
# 📅 2012년 가장 많이 등장한 키워드 (TF 상위 10개):
# 朝鲜: 525회
# 美国: 486회
# 日本: 393회
# 日: 347회
# 韩国: 346회
# 韩: 323회
# 美: 278회
# 中国: 258회
# 一: 252회
# 这: 230회
#
# 📅 2013년 가장 많이 등장한 키워드 (TF 상위 10개):
# 朝鲜: